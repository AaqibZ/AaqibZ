# %% [markdown]
# <a href="https://colab.research.google.com/github/AaqibZ/AaqibZ/blob/main/GNN_Candidate_IM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -r requirement.txt
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from -r requirement.txt (line 1)) (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from -r requirement.txt (line 2)) (0.21.0+cu124)
# Collecting dgl (from -r requirement.txt (line 3))
#   Downloading dgl-2.1.0-cp311-cp311-manylinux1_x86_64.whl.metadata (553 bytes)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from -r requirement.txt (line 4)) (3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from -r requirement.txt (line 5)) (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from -r requirement.txt (line 6)) (1.6.1)
# Collecting pickle5 (from -r requirement.txt (line 7))
#   Downloading pickle5-0.0.11.tar.gz (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.1/132.1 kB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->-r requirement.txt (line 1)) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirement.txt (line 1)) (4.14.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirement.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->-r requirement.txt (line 1)) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->-r requirement.txt (line 1))
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->-r requirement.txt (line 1))
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->-r requirement.txt (line 1))
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->-r requirement.txt (line 1))
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->-r requirement.txt (line 1))
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->-r requirement.txt (line 1))
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->-r requirement.txt (line 1))
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->-r requirement.txt (line 1))
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->-r requirement.txt (line 1))
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirement.txt (line 1)) (0.6.2)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch->-r requirement.txt (line 1))
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirement.txt (line 1)) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->-r requirement.txt (line 1))
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirement.txt (line 1)) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirement.txt (line 1)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->-r requirement.txt (line 1)) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision->-r requirement.txt (line 2)) (11.3.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from dgl->-r requirement.txt (line 3)) (1.16.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from dgl->-r requirement.txt (line 3)) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from dgl->-r requirement.txt (line 3)) (4.67.1)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.11/dist-packages (from dgl->-r requirement.txt (line 3)) (5.9.5)
# Requirement already satisfied: torchdata>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from dgl->-r requirement.txt (line 3)) (0.11.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->-r requirement.txt (line 6)) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->-r requirement.txt (line 6)) (3.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->dgl->-r requirement.txt (line 3)) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->dgl->-r requirement.txt (line 3)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->dgl->-r requirement.txt (line 3)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->dgl->-r requirement.txt (line 3)) (2025.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->-r requirement.txt (line 1)) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 90.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 60.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.0 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 72.7 MB/s eta 0:00:00
# Downloading dgl-2.1.0-cp311-cp311-manylinux1_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 56.2 MB/s eta 0:00:00
# Building wheels for collected packages: pickle5
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for pickle5 (setup.py) ... error
#   ERROR: Failed building wheel for pickle5
#   Running setup.py clean for pickle5
# Failed to build pickle5
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (pickle5)

# %%
import networkx as nx
import random
import os

# %%
import networkx as nx
import os
import random
import pickle   # <-- added

def generate_dynamic_endo_syni(num_initial_nodes=50, num_snapshots=10, num_final_nodes=500, edges_per_snapshot=20, output_dir="dynamic_endo_syni"):
    """
    Generate a dynamic Endo-Syni graph with expansion over multiple snapshots.

    Args:
        num_initial_nodes (int): Number of nodes in the initial graph.
        num_snapshots (int): Number of snapshots to generate.
        num_final_nodes (int): Total number of nodes by the final snapshot.
        edges_per_snapshot (int): Number of edges to add in each snapshot.
        output_dir (str): Directory to save snapshots as Pickle files.
    """
    # Ensure the output directory exists
    os.makedirs(output_dir, exist_ok=True)

    # Initialize the graph with a small number of nodes and edges
    G = nx.Graph()
    G.add_nodes_from(range(num_initial_nodes))
    for _ in range(num_initial_nodes // 2):
        u, v = random.sample(range(num_initial_nodes), 2)
        G.add_edge(u, v)

    # Save the initial snapshot
    filename = os.path.join(output_dir, "snapshot_0.pkl")
    with open(filename, "wb") as f:
        pickle.dump(G, f)
    print(f"Snapshot 0 saved: Nodes = {G.number_of_nodes()}, Edges = {G.number_of_edges()}")

    # Incrementally expand the graph
    for snapshot in range(1, num_snapshots):
        # Add new nodes
        current_nodes = G.number_of_nodes()
        new_nodes = int(num_initial_nodes + (num_final_nodes - num_initial_nodes) * snapshot / (num_snapshots - 1))
        for node in range(current_nodes, new_nodes):
            G.add_node(node)

        # Add edges based on Endo-Syni dynamics
        for _ in range(edges_per_snapshot):
            # Endogenous growth: Preferential attachment (connect to high-degree nodes)
            u = random.choices(list(G.nodes), weights=dict(G.degree).values(), k=1)[0]
            v = random.choice(list(G.nodes))
            if u != v and not G.has_edge(u, v):
                G.add_edge(u, v)

            # Synergistic dynamics: Connect hubs to each other
            hubs = sorted(G.degree, key=lambda x: x[1], reverse=True)[:10]  # Top 10 hubs
            if len(hubs) >= 2:
                hub_u, hub_v = random.sample([hub[0] for hub in hubs], 2)
                if not G.has_edge(hub_u, hub_v):
                    G.add_edge(hub_u, hub_v)

        # Save the snapshot
        filename = os.path.join(output_dir, f"snapshot_{snapshot}.pkl")
        try:
            with open(filename, "wb") as f:
                pickle.dump(G, f)
            print(f"Snapshot {snapshot} saved: Nodes = {G.number_of_nodes()}, Edges = {G.number_of_edges()}")
        except Exception as e:
            print(f"Error saving snapshot {snapshot}: {e}")

# %%
output_dir = "/content/endo_syni_snapshots_1000/"

# make sure the directory exists
import os
os.makedirs(output_dir, exist_ok=True)

# Generate a dynamic Endo-Syni graph
generate_dynamic_endo_syni(
    num_initial_nodes=500,
    num_snapshots=13,
    num_final_nodes=1000,
    edges_per_snapshot=50,
    output_dir=output_dir
)
# Out:
# Snapshot 0 saved: Nodes = 500, Edges = 250
# Snapshot 1 saved: Nodes = 541, Edges = 332
# Snapshot 2 saved: Nodes = 583, Edges = 390
# Snapshot 3 saved: Nodes = 625, Edges = 443
# Snapshot 4 saved: Nodes = 666, Edges = 493
# Snapshot 5 saved: Nodes = 708, Edges = 543
# Snapshot 6 saved: Nodes = 750, Edges = 593
# Snapshot 7 saved: Nodes = 791, Edges = 643
# Snapshot 8 saved: Nodes = 833, Edges = 692
# Snapshot 9 saved: Nodes = 875, Edges = 742
# Snapshot 10 saved: Nodes = 916, Edges = 792
# Snapshot 11 saved: Nodes = 958, Edges = 841
# Snapshot 12 saved: Nodes = 1000, Edges = 891

# %%
import os
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import random

# %%
import os
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt


class GraphProcessor:
    def __init__(self, input_dir=None, output_dir=None, uniinfweight=1.0):
        """
        Initialize the GraphProcessor class.

        Parameters:
            input_dir (str): Directory containing input graphs (optional).
            output_dir (str): Directory to save processed graphs (optional).
        """
        self.uniinfweight = uniinfweight
        self.input_dir = input_dir
        self.output_dir = output_dir

    def calculate_ifc_score(self, G):
        nodelist = list(G.nodes)
        il = {}  # Local influence scores
        ig = {}  # Global influence scores

        degn = len(nodelist)

        for countnode, node in enumerate(nodelist):
            tempw = 0
            for neighbnode in G.neighbors(node):
                tempw += self.uniinfweight * self.uniinfweight * nx.degree(G, neighbnode)

            # Local score
            il[node] = 1 + list(G.degree([node], weight='weight'))[0][1] + tempw

            # Global score
            ig[node] = nx.core_number(G)[node] * (
                1 + (nx.degree(G, node)) / degn
            )

        # Combine local and global scores into a tuple
        ifc_scores = {node: (il[node], ig[node]) for node in nodelist}

        return ifc_scores


    def add_features_to_graph(self, G):
        # Calculate graph metrics
        degree = dict(G.degree())
        betweenness = nx.betweenness_centrality(G)
        k_core = nx.core_number(G)
        avg_neighbor_degree = nx.average_neighbor_degree(G)
        ifc_scores = self.calculate_ifc_score(G)

        # Add features to nodes
        for node in G.nodes:
            if node not in ifc_scores or len(ifc_scores[node]) < 1:
                print(f"Skipping node {node}: IFC scores missing or invalid")
                continue  # Skip this node if IFC scores are not valid

            # Add features
            G.nodes[node]["features"] = [
                degree[node],
                betweenness[node],
                k_core[node],
                avg_neighbor_degree[node],
                ifc_scores[node][0],  # Local influence score
            ]

        return G

    def add_labels_to_graph(self, G, top_percentage=40):
        """
        Add labels to ensure exactly `top_percentage` of nodes are labeled `1` based on IFC score.

        Parameters:
            G (networkx.Graph): The graph object.
            top_percentage (float): Percentage of nodes to label as `1` (default is 30%).

        Returns:
            networkx.Graph: The graph with labeled nodes.
        """
        # Extract IFC scores and sort nodes by IFC score in descending order
        nodes_with_scores = [(node, G.nodes[node]["features"][-1]) for node in G.nodes]
        sorted_nodes = sorted(nodes_with_scores, key=lambda x: x[1], reverse=True)

        # Determine the number of nodes to label as `1`
        num_top_nodes = int(len(sorted_nodes) * top_percentage / 100)

        # Label top `num_top_nodes` as `1` and the rest as `0`
        for i, (node, _) in enumerate(sorted_nodes):
            G.nodes[node]["label"] = 1 if i < num_top_nodes else 0

        return G

    def process_graphs(self):
        """
        Process all graphs in the input directory:
        - Add features
        - Add labels
        - Save the modified graphs
        """
        for file_name in os.listdir(self.input_dir):
            if file_name.endswith(".gpickle"):
                graph_path = os.path.join(self.input_dir, file_name)

                # Load the graph
                G = nx.read_gpickle(graph_path)

                # Add features and labels
                G = self.add_features_to_graph(G)
                G = self.add_labels_to_graph(G)

                # Save the modified graph
                output_path = os.path.join(self.output_dir, file_name)
                nx.write_gpickle(G, output_path)
                print(f"Processed and saved graph: {output_path}")

# %%
import numpy as np
import time

class InfluenceMaximization:
    def __init__(self, graph, propagation_probability=0.5, monte_carlo=10):
        """
        Initialize the Influence Maximization class.

        Parameters:
            graph (networkx.Graph): The graph object.
            propagation_probability (float): Propagation probability.
            monte_carlo (int): Number of Monte Carlo simulations.
        """
        self.graph = graph
        self.p = propagation_probability
        self.mc = monte_carlo

    def influence_spread(self, S):
        """
        Calculate the influence spread using the Independent Cascade (IC) model.

        Parameters:
            S (list): Set of seed nodes.

        Returns:
            float: Average number of nodes influenced by the seed nodes.
        """
        spread = []  # Store the spread for each Monte Carlo simulation

        for i in range(self.mc):
            # Simulate the propagation process
            new_active, A = S[:], S[:]  # Initialize active nodes

            while new_active:
                new_ones = []
                for node in new_active:
                    # Randomly activate neighbors based on propagation probability
                    np.random.seed(i)
                    neighbors = list(self.graph.neighbors(node))
                    success = np.random.uniform(0, 1, len(neighbors)) < self.p
                    new_ones += list(np.extract(success, neighbors))

                # Deduplicate and find newly activated nodes
                new_active = list(set(new_ones) - set(A))
                A += new_active  # Add newly activated nodes to the influenced set

            spread.append(len(A))  # Store the total spread for this simulation

        return np.mean(spread)  # Average spread over all simulations

    def greedy(self, k):
        """
        Greedy algorithm for influence maximization.

        Parameters:
            k (int): Number of seed nodes to select.

        Returns:
            tuple: (optimal seed set, resulting spread, elapsed time per iteration)
        """
        S, spread, timelapse = [], [], []
        start_time = time.time()

        for _ in range(k):
            best_spread = 0
            for j in set(self.graph.nodes()) - set(S):
                # Calculate the spread if j is added to the seed set
                s = self.influence_spread(S + [j])
                if s > best_spread:
                    best_spread, node = s, j

            # Add the selected node to the seed set
            S.append(node)
            spread.append(best_spread)
            timelapse.append(time.time() - start_time)

        return S, spread, timelapse

    def greedy_mod(self, k, candidatenodelist):
        """
        Heuristic-based greedy algorithm for influence maximization.

        Parameters:
            k (int): Number of seed nodes to select.
            candidatenodelist (list): List of candidate nodes for seeding.

        Returns:
            tuple: (heuristic seed set, resulting spread, elapsed time per iteration)
        """
        S, spread, timelapse = [], [], []
        start_time = time.time()

        for _ in range(k):
            best_spread = 0
            for j in set(candidatenodelist) - set(S):
                # Calculate the spread if j is added to the seed set
                s = self.influence_spread(S + [j])
                if s > best_spread:
                    best_spread, node = s, j

            # Add the selected node to the seed set
            S.append(node)
            spread.append(best_spread)
            timelapse.append(time.time() - start_time)

        return S, spread, timelapse

# %%
#Create Dynamic Graph
import sys
import os
os.path.join(os.getcwd())
import matplotlib; print(matplotlib.__version__)
import pandas as pd
import numpy as np
import networkx as nx
from datetime import date, timedelta
import networkx as nx
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
# Out:
# 3.10.0

# %%
#IMutil
import pandas as pd
import numpy as np
import networkx as nx
from datetime import date, timedelta
import networkx as nx
from matplotlib import pyplot as plt
import pandas as pd


class IMutil():
    def __init__(self):
        print("IM hep class is invoked")

    # # get IFC centrality score for each node
    # def get_inflcapapcity(self, g, uniinfweight):
    #     nodelist = list(g.nodes)
    #     il = np.zeros((len(nodelist), 1))
    #     ig = np.zeros((len(nodelist), 1))

    #     degn = max([nx.degree(g, ind) for ind in g.nodes])

    #     for countnode in range(len(nodelist)):
    #         tempw = 0
    #         for neighbnode in g.neighbors(nodelist[countnode]):
    #             tempw = tempw + uniinfweight * uniinfweight * nx.degree(g, neighbnode)

    #         # local score
    #         il[nodelist[countnode]] = 1 + list(g.degree([nodelist[countnode]], weight='weight'))[0][1] + tempw

    #         # global score
    #         ig[nodelist[countnode]] = nx.core_number(g)[nodelist[countnode]] * (
    #                     1 + (nx.degree(g, nodelist[countnode])) / (degn))

    #     # overall score
    #     ic = np.array([(il[nodelist[countnode]] / np.max(il)) * (ig[nodelist[countnode]] / np.max(ig)) for countnode in
    #                    range(len(nodelist))])

    #     return ic

    def calculate_ifc_score(G, uniinfweight=1.0):
        """
        Calculate the Influence Capacity (IFC) score for each node in the graph.

        Parameters:
            G (networkx.Graph): Input graph.
            uniinfweight (float): Weight factor for influence score calculation.

        Returns:
            dict: A dictionary mapping nodes to their IFC scores.
        """
        nodelist = list(G.nodes)
        il = np.zeros(len(nodelist))  # Local influence scores
        ig = np.zeros(len(nodelist))  # Global influence scores

        degn = max(dict(G.degree()).values())  # Maximum degree for normalization

        for idx, node in enumerate(nodelist):
            # Calculate local influence
            tempw = sum(uniinfweight * G.degree(neighb) for neighb in G.neighbors(node))
            il[idx] = 1 + G.degree(node) + tempw

            # Calculate global influence
            ig[idx] = nx.core_number(G)[node] * (1 + G.degree(node) / degn)

        # Normalize and calculate overall IFC score
        il_norm = il / np.max(il) if np.max(il) > 0 else il
        ig_norm = ig / np.max(ig) if np.max(ig) > 0 else ig
        ic_scores = il_norm * ig_norm

        return {node: ic_scores[idx] for idx, node in enumerate(nodelist)}

# %%
# Download and unzip
# !wget -q https://snap.stanford.edu/data/soc-sign-bitcoinalpha.csv.gz -O /content/soc-sign-bitcoinalpha.csv.gz
# !gunzip -f /content/soc-sign-bitcoinalpha.csv.gz

# Check file
# !ls -lh /content/soc-sign-bitcoinalpha.csv
# Out:
# -rw-r--r-- 1 root root 492K Oct  6  2017 /content/soc-sign-bitcoinalpha.csv

# %%
# !wget -q https://snap.stanford.edu/data/email-Eu-core-temporal.txt.gz -O /content/email-Eu-core-temporal.txt.gz
# !gunzip -f /content/email-Eu-core-temporal.txt.gz

# !ls -lh /content/email-Eu-core-temporal.txt
# Out:
# -rw-r--r-- 1 root root 5.3M Jun  5  2017 /content/email-Eu-core-temporal.txt

# %%
import sys
import os
os.path.join(os.getcwd())
import matplotlib; print(matplotlib.__version__)
import pandas as pd
import numpy as np
import networkx as nx
from datetime import date, timedelta
import networkx as nx
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
# Out:
# 3.10.0

# %%
# ✅ Step 3: Read the dataset
df = pd.read_csv("soc-sign-bitcoinalpha.csv", header=None)

# Show first 5 rows
df.head()
# Out:
#       0  1   2           3
# 0  7188  1  10  1407470400
# 1   430  1  10  1376539200
# 2  3134  1  10  1369713600
# 3  3026  1  10  1350014400
# 4  3010  1  10  1347854400

# %%
# ✅ Step 4: Rename the columns for clarity
df.rename(columns={0: "source", 1: "target", 2: "rating", 3: "timestamp"}, inplace=True)

# Show first 5 rows after renaming
df.head()
# Out:
#    source  target  rating   timestamp
# 0    7188       1      10  1407470400
# 1     430       1      10  1376539200
# 2    3134       1      10  1369713600
# 3    3026       1      10  1350014400
# 4    3010       1      10  1347854400

# %%
# ✅ Step 5: Show dataset info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24186 entries, 0 to 24185
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   source     24186 non-null  int64
#  1   target     24186 non-null  int64
#  2   rating     24186 non-null  int64
#  3   timestamp  24186 non-null  int64
# dtypes: int64(4)
# memory usage: 755.9 KB

# %%
# Drop duplicate edges based on source and target (keep first occurrence)
df = df.drop_duplicates(
    subset=['source', 'target'],
    keep='first'
).reset_index(drop=True)

# Convert unix timestamp to pandas datetime
df['date'] = pd.to_datetime(df['timestamp'], unit="s")

# Show dataframe with new datetime column
df['date']
# Out:
# 0       2014-08-08 04:00:00
# 1       2013-08-15 04:00:00
# 2       2013-05-28 04:00:00
# 3       2012-10-12 04:00:00
# 4       2012-09-17 04:00:00
#                 ...
# 24181   2013-03-26 04:00:00
# 24182   2013-03-26 04:00:00
# 24183   2013-03-26 04:00:00
# 24184   2013-03-26 04:00:00
# 24185   2013-03-26 04:00:00
# Name: date, Length: 24186, dtype: datetime64[ns]

# %%
# Grouping by year and month from the 'date' column
grouped = df.groupby([df['date'].dt.year, df['date'].dt.month])

# Display group sizes
grouped.size()
# Out:
# date  date
# 2010  11       41
#       12       57
# 2011  1        67
#       2       188
#       3       175
#              ...
# 2015  9        25
#       10       20
#       11        9
#       12       38
# 2016  1        17
# Length: 63, dtype: int64

# %%
grouped

# %%
# Access the last group
last_group = grouped.get_group(max(grouped.groups))
last_group
# Out:
#        source  target  rating   timestamp                date
# 5252     3447      15       3  1451797200 2016-01-03 05:00:00
# 5382       15    3451       1  1453438800 2016-01-22 05:00:00
# 5383       15    2437       1  1452834000 2016-01-15 05:00:00
# 5384       15    3443       1  1452747600 2016-01-14 05:00:00
# 5385       15    3448       1  1452747600 2016-01-14 05:00:00
# 5386       15    1396       1  1452488400 2016-01-11 05:00:00
# 11202     953      64       3  1452315600 2016-01-09 05:00:00
# 13594    3451      98       5  1453438800 2016-01-22 05:00:00
# 13889     104    2437       1  1452834000 2016-01-15 05:00:00
# 14393     114    7370      -1  1453006800 2016-01-17 05:00:00
# 19115     906     279       1  1452920400 2016-01-16 05:00:00
# 19152     281    3450       1  1452920400 2016-01-16 05:00:00
# 21252     906     499       1  1452142800 2016-01-07 05:00:00
# 21812    1202     604       1  1452920400 2016-01-16 05:00:00
# 21814     604    1202       1  1452920400 2016-01-16 05:00:00
# 22992     953    1390       2  1452315600 2016-01-09 05:00:00
# 23922    2336    3449       1  1452747600 2016-01-14 05:00:00

# %%
# Filter rows where the year is 2026
df_2016 = df[df['date'].dt.year == 2016]

# %%
df_2016
# Out:
#        source  target  rating   timestamp                date
# 5252     3447      15       3  1451797200 2016-01-03 05:00:00
# 5382       15    3451       1  1453438800 2016-01-22 05:00:00
# 5383       15    2437       1  1452834000 2016-01-15 05:00:00
# 5384       15    3443       1  1452747600 2016-01-14 05:00:00
# 5385       15    3448       1  1452747600 2016-01-14 05:00:00
# 5386       15    1396       1  1452488400 2016-01-11 05:00:00
# 11202     953      64       3  1452315600 2016-01-09 05:00:00
# 13594    3451      98       5  1453438800 2016-01-22 05:00:00
# 13889     104    2437       1  1452834000 2016-01-15 05:00:00
# 14393     114    7370      -1  1453006800 2016-01-17 05:00:00
# 19115     906     279       1  1452920400 2016-01-16 05:00:00
# 19152     281    3450       1  1452920400 2016-01-16 05:00:00
# 21252     906     499       1  1452142800 2016-01-07 05:00:00
# 21812    1202     604       1  1452920400 2016-01-16 05:00:00
# 21814     604    1202       1  1452920400 2016-01-16 05:00:00
# 22992     953    1390       2  1452315600 2016-01-09 05:00:00
# 23922    2336    3449       1  1452747600 2016-01-14 05:00:00

# %%
# Find the minimum node number
min_node_number = min(df['source'].min(), df['target'].min())

min_node_number

# Subtract the minimum node number to shift node numbers to start from 0
# df['source'] -= min_node_number
# df['target'] -= min_node_number
# Out:
# 1

# %%
#get maximum element from row & column to get the number of nodes
max_node = max(df['source'].max(),df['target'].max())
print("Maximum", max_node )
# Out:
# Maximum 7604

# %%
def graph_details(graph_dir):
    # Iterate over the gpickle files in the directory
    for file_name in os.listdir(graph_dir):
        if file_name.endswith('.gpickle'):
            # Construct the full file path
            file_path = os.path.join(graph_dir, file_name)

            # Load the graph from the gpickle file
            graph = nx.read_gpickle(file_path)

            # Get the number of nodes and edges
            num_nodes = graph.number_of_nodes()
            num_edges = graph.number_of_edges()

            # Print the number of nodes and edges
            print(f"Graph: {file_name}", "Number of nodes & edges :", num_nodes,  num_edges)
    return 1

# %%
import os
import pickle
import networkx as nx

# Example graph_dir (change path if needed)
graph_dir = "/content/bitcoin-alpha-snapshots"

# Create the directory if it doesn't exist
if not os.path.exists(graph_dir):
    os.makedirs(graph_dir)

previous_snapshot = nx.DiGraph()  # Initialize an empty directed graph for the previous snapshot

# Create a graph with nodes ranging from 0 to 7604
nodes = list(range(7605))
previous_snapshot.add_nodes_from(nodes)

count = 0
for timestamp, group in grouped:
    g = previous_snapshot.copy()  # Create a copy of the previous snapshot

    # Iterate through the DataFrame and add new edges with weight=1
    for index, row in group.iterrows():
        source = row['source']
        target = row['target']
        g.add_edge(source, target, weight=1)

    # Remove self-loops
    g.remove_edges_from(nx.selfloop_edges(g))

    # Save the graph as a pickle file (instead of gpickle)
    filename_pickle = os.path.join(graph_dir, f"snapshot_{count}.pkl")
    with open(filename_pickle, "wb") as f:
        pickle.dump(g, f)

    # Save the graph as an edgelist with weight=1
    filename_edgelist = os.path.join(graph_dir, f"snapshot_{count}.edgelist")
    nx.write_weighted_edgelist(g, filename_edgelist, delimiter=" ", comments="")

    count += 1
    previous_snapshot = g  # Update snapshot for next iteration

# %%
graph_dir = "/content/bitcoin-alpha-snapshots"


# Create the directory if it doesn't exist
if not os.path.exists(graph_dir):
    os.makedirs(graph_dir)

previous_snapshot = nx.DiGraph()  # Initialize an empty directed graph for the previous snapshot

# Create a graph with nodes ranging from 0 to 319
nodes = list(range(7604))
previous_snapshot.add_nodes_from(nodes)

count=0
for timestamp, group in grouped:
    g = previous_snapshot.copy()  # Create a copy of the previous snapshot

    # Iterate through the DataFrame and add new edges with weight 1
    for index, row in group.iterrows():
        source = row['source']
        target = row['target']
        g.add_edge(source, target, weight=1)

    # Remove self-loops
    g.remove_edges_from(nx.selfloop_edges(g))

    # Save the graph as a gpickle file
    filename_gpickle = os.path.join(graph_dir, f"snapshot_{count}.gpickle")
    with open(filename_gpickle, "wb") as f:
       pickle.dump(g, f)


    # Save the graph as an edgelist with weight=1
    filename_edgelist = os.path.join(graph_dir, f"snapshot_{count}.edgelist")
    nx.write_weighted_edgelist(g, filename_edgelist, delimiter=' ', comments='')
    count= count+1
    # Update the previous snapshot to the current graph for the next iteration
    previous_snapshot = g

# %%
timestamp
# Out:
# 1453438800

# %%
import os
import pickle
import networkx as nx

def graph_details(graph_dir):
    snapshots = sorted([f for f in os.listdir(graph_dir) if f.endswith(".gpickle")])
    print(f"Total snapshots found: {len(snapshots)}\n")

    for i, file in enumerate(snapshots):
        path = os.path.join(graph_dir, file)
        # ✅ Load snapshot using pickle instead of nx.read_gpickle
        with open(path, "rb") as f:
            g = pickle.load(f)

        print(f"Snapshot {i}: {file}")
        print(f"  Nodes: {g.number_of_nodes()}")
        print(f"  Edges: {g.number_of_edges()}")
        print(f"  Density: {nx.density(g):.6f}")
        print(f"  Is Directed: {g.is_directed()}")
        print("-" * 40)

# ✅ Run after generating snapshots
graph_details(graph_dir)
# Out:
# Streaming output truncated to the last 5000 lines.
#   Is Directed: True
# ----------------------------------------
# Snapshot 814: snapshot_249.gpickle
#   Nodes: 7604
#   Edges: 6180
#   Density: 0.000107
#   Is Directed: True
# ----------------------------------------
# Snapshot 815: snapshot_25.gpickle
#   Nodes: 7604
#   Edges: 63
#   Density: 0.000001
#   Is Directed: True
# ----------------------------------------
# Snapshot 816: snapshot_250.gpickle
#   Nodes: 7604
#   Edges: 6201
#   Density: 0.000107
#   Is Directed: True
# ----------------------------------------
# Snapshot 817: snapshot_251.gpickle
#   Nodes: 7604
#   Edges: 6224
#   Density: 0.000108
#   Is Directed: True
# ----------------------------------------
# Snapshot 818: snapshot_252.gpickle
#   Nodes: 7604
#   Edges: 6243
#   Density: 0.000108
#   Is Directed: True
# ----------------------------------------
# Snapshot 819: snapshot_253.gpickle
#   Nodes: 7604
#   Edges: 6254
#   Density: 0.000108
#   Is Directed: True
# ----------------------------------------
# Snapshot 820: snapshot_254.gpickle
#   Nodes: 7604
#   Edges: 6269
#   Density: 0.000108
#   Is Directed: True
# ----------------------------------------
# Snapshot 821: snapshot_255.gpickle
#   Nodes: 7604
#   Edges: 6279
#   Density: 0.000109
#   Is Directed: True
# ----------------------------------------
# Snapshot 822: snapshot_256.gpickle
#   Nodes: 7604
#   Edges: 6280
#   Density: 0.000109
#   Is Directed: True
# ----------------------------------------
# Snapshot 823: snapshot_257.gpickle
#   Nodes: 7604
#   Edges: 6291
#   Density: 0.000109
#   Is Directed: True
# ----------------------------------------
# Snapshot 824: snapshot_258.gpickle
#   Nodes: 7604
#   Edges: 6315
#   Density: 0.000109
#   Is Directed: True
# ----------------------------------------
# Snapshot 825: snapshot_259.gpickle
#   Nodes: 7604
#   Edges: 6328
#   Density: 0.000109
#   Is Directed: True
# ----------------------------------------
# Snapshot 826: snapshot_26.gpickle
#   Nodes: 7604
#   Edges: 65
#   Density: 0.000001
#   Is Directed: True
# ----------------------------------------
# Snapshot 827: snapshot_260.gpickle
#   Nodes: 7604
#   Edges: 6341
#   Density: 0.000110
#   Is Directed: True
# ----------------------------------------
# Snapshot 828: snapshot_261.gpickle
#   Nodes: 7604
#   Edges: 6351
#   Density: 0.000110
#   Is Directed: True
# ----------------------------------------
# Snapshot 829: snapshot_262.gpickle
#   Nodes: 7604
#   Edges: 6363
#   Density: 0.000110
#   Is Directed: True
# ----------------------------------------
# Snapshot 830: snapshot_263.gpickle
#   Nodes: 7604
#   Edges: 6378
#   Density: 0.000110
#   Is Directed: True
# ----------------------------------------
# Snapshot 831: snapshot_264.gpickle
#   Nodes: 7604
#   Edges: 6397
#   Density: 0.000111
#   Is Directed: True
# ----------------------------------------
# Snapshot 832: snapshot_265.gpickle
#   Nodes: 7604
#   Edges: 6410
#   Density: 0.000111
#   Is Directed: True
# ----------------------------------------
# Snapshot 833: snapshot_266.gpickle
#   Nodes: 7604
#   Edges: 6429
#   Density: 0.000111
#   Is Directed: True
# ----------------------------------------
# Snapshot 834: snapshot_267.gpickle
#   Nodes: 7604
#   Edges: 6439
#   Density: 0.000111
#   Is Directed: True
# ----------------------------------------
# Snapshot 835: snapshot_268.gpickle
#   Nodes: 7604
#   Edges: 6447
#   Density: 0.000112
#   Is Directed: True
# ----------------------------------------
# Snapshot 836: snapshot_269.gpickle
#   Nodes: 7604
#   Edges: 6473
#   Density: 0.000112
#   Is Directed: True
# ----------------------------------------
# Snapshot 837: snapshot_27.gpickle
#   Nodes: 7604
#   Edges: 66
#   Density: 0.000001
#   Is Directed: True
# ----------------------------------------
# Snapshot 838: snapshot_270.gpickle
#   Nodes: 7604
#   Edges: 6483
#   Density: 0.000112
#   Is Directed: True
# ----------------------------------------
# Snapshot 839: snapshot_271.gpickle
#   Nodes: 7604
#   Edges: 6484
#   Density: 0.000112
#   Is Directed: True
# ----------------------------------------
# Snapshot 840: snapshot_272.gpickle
#   Nodes: 7604
#   Edges: 6501
#   Density: 0.000112
#   Is Directed: True
# ----------------------------------------
# Snapshot 841: snapshot_273.gpickle
#   Nodes: 7604
#   Edges: 6508
#   Density: 0.000113
#   Is Directed: True
# ----------------------------------------
# Snapshot 842: snapshot_274.gpickle
#   Nodes: 7604
#   Edges: 6517
#   Density: 0.000113
#   Is Directed: True
# ----------------------------------------
# Snapshot 843: snapshot_275.gpickle
#   Nodes: 7604
#   Edges: 6528
#   Density: 0.000113
#   Is Directed: True
# ----------------------------------------
# Snapshot 844: snapshot_276.gpickle
#   Nodes: 7604
#   Edges: 6540
#   Density: 0.000113
#   Is Directed: True
# ----------------------------------------
# Snapshot 845: snapshot_277.gpickle
#   Nodes: 7604
#   Edges: 6547
#   Density: 0.000113
#   Is Directed: True
# ----------------------------------------
# Snapshot 846: snapshot_278.gpickle
#   Nodes: 7604
#   Edges: 6557
#   Density: 0.000113
#   Is Directed: True
# ----------------------------------------
# Snapshot 847: snapshot_279.gpickle
#   Nodes: 7604
#   Edges: 6566
#   Density: 0.000114
#   Is Directed: True
# ----------------------------------------
# Snapshot 848: snapshot_28.gpickle
#   Nodes: 7604
#   Edges: 69
#   Density: 0.000001
#   Is Directed: True
# ----------------------------------------
# Snapshot 849: snapshot_280.gpickle
#   Nodes: 7604
#   Edges: 6584
#   Density: 0.000114
#   Is Directed: True
# ----------------------------------------
# Snapshot 850: snapshot_281.gpickle
#   Nodes: 7604
#   Edges: 6599
#   Density: 0.000114
#   Is Directed: True
# ----------------------------------------
# Snapshot 851: snapshot_282.gpickle
#   Nodes: 7604
#   Edges: 6615
#   Density: 0.000114
#   Is Directed: True
# ----------------------------------------
# Snapshot 852: snapshot_283.gpickle
#   Nodes: 7604
#   Edges: 6621
#   Density: 0.000115
#   Is Directed: True
# ----------------------------------------
# Snapshot 853: snapshot_284.gpickle
#   Nodes: 7604
#   Edges: 6628
#   Density: 0.000115
#   Is Directed: True
# ----------------------------------------
# Snapshot 854: snapshot_285.gpickle
#   Nodes: 7604
#   Edges: 6634
#   Density: 0.000115
#   Is Directed: True
# ----------------------------------------
# Snapshot 855: snapshot_286.gpickle
#   Nodes: 7604
#   Edges: 6642
#   Density: 0.000115
#   Is Directed: True
# ----------------------------------------
# Snapshot 856: snapshot_287.gpickle
#   Nodes: 7604
#   Edges: 6669
#   Density: 0.000115
#   Is Directed: True
# ----------------------------------------
# Snapshot 857: snapshot_288.gpickle
#   Nodes: 7604
#   Edges: 6675
#   Density: 0.000115
#   Is Directed: True
# ----------------------------------------
# Snapshot 858: snapshot_289.gpickle
#   Nodes: 7604
#   Edges: 6682
#   Density: 0.000116
#   Is Directed: True
# ----------------------------------------
# Snapshot 859: snapshot_29.gpickle
#   Nodes: 7604
#   Edges: 72
#   Density: 0.000001
#   Is Directed: True
# ----------------------------------------
# Snapshot 860: snapshot_290.gpickle
#   Nodes: 7604
#   Edges: 6684
#   Density: 0.000116
#   Is Directed: True
# ----------------------------------------
# Snapshot 861: snapshot_291.gpickle
#   Nodes: 7604
#   Edges: 6686
#   Density: 0.000116
#   Is Directed: True
# ----------------------------------------
# Snapshot 862: snapshot_292.gpickle
#   Nodes: 7604
#   Edges: 6689
#   Density: 0.000116
#   Is Directed: True
# ----------------------------------------
# Snapshot 863: snapshot_293.gpickle
#   Nodes: 7604
#   Edges: 6692
#   Density: 0.000116
#   Is Directed: True
# ----------------------------------------
# Snapshot 864: snapshot_294.gpickle
#   Nodes: 7604
#   Edges: 6698
#   Density: 0.000116
#   Is Directed: True
# ----------------------------------------
# Snapshot 865: snapshot_295.gpickle
#   Nodes: 7604
#   Edges: 6709
#   Density: 0.000116
#   Is Directed: True
# ----------------------------------------
# Snapshot 866: snapshot_296.gpickle
#   Nodes: 7604
#   Edges: 6718
#   Density: 0.000116
#   Is Directed: True
# ----------------------------------------
# Snapshot 867: snapshot_297.gpickle
#   Nodes: 7604
#   Edges: 6721
#   Density: 0.000116
#   Is Directed: True
# ----------------------------------------
# Snapshot 868: snapshot_298.gpickle
#   Nodes: 7604
#   Edges: 6727
#   Density: 0.000116
#   Is Directed: True
# ----------------------------------------
# Snapshot 869: snapshot_299.gpickle
#   Nodes: 7604
#   Edges: 6732
#   Density: 0.000116
#   Is Directed: True
# ----------------------------------------
# Snapshot 870: snapshot_3.gpickle
#   Nodes: 7604
#   Edges: 15
#   Density: 0.000000
#   Is Directed: True
# ----------------------------------------
# Snapshot 871: snapshot_30.gpickle
#   Nodes: 7604
#   Edges: 74
#   Density: 0.000001
#   Is Directed: True
# ----------------------------------------
# Snapshot 872: snapshot_300.gpickle
#   Nodes: 7604
#   Edges: 6748
#   Density: 0.000117
#   Is Directed: True
# ----------------------------------------
# Snapshot 873: snapshot_301.gpickle
#   Nodes: 7604
#   Edges: 6751
#   Density: 0.000117
#   Is Directed: True
# ----------------------------------------
# Snapshot 874: snapshot_302.gpickle
#   Nodes: 7604
#   Edges: 6761
#   Density: 0.000117
#   Is Directed: True
# ----------------------------------------
# Snapshot 875: snapshot_303.gpickle
#   Nodes: 7604
#   Edges: 6767
#   Density: 0.000117
#   Is Directed: True
# ----------------------------------------
# Snapshot 876: snapshot_304.gpickle
#   Nodes: 7604
#   Edges: 6776
#   Density: 0.000117
#   Is Directed: True
# ----------------------------------------
# Snapshot 877: snapshot_305.gpickle
#   Nodes: 7604
#   Edges: 6779
#   Density: 0.000117
#   Is Directed: True
# ----------------------------------------
# Snapshot 878: snapshot_306.gpickle
#   Nodes: 7604
#   Edges: 6789
#   Density: 0.000117
#   Is Directed: True
# ----------------------------------------
# Snapshot 879: snapshot_307.gpickle
#   Nodes: 7604
#   Edges: 6796
#   Density: 0.000118
#   Is Directed: True
# ----------------------------------------
# Snapshot 880: snapshot_308.gpickle
#   Nodes: 7604
#   Edges: 6807
#   Density: 0.000118
#   Is Directed: True
# ----------------------------------------
# Snapshot 881: snapshot_309.gpickle
#   Nodes: 7604
#   Edges: 6810
#   Density: 0.000118
#   Is Directed: True
# ----------------------------------------
# Snapshot 882: snapshot_31.gpickle
#   Nodes: 7604
#   Edges: 75
#   Density: 0.000001
#   Is Directed: True
# ----------------------------------------
# Snapshot 883: snapshot_310.gpickle
#   Nodes: 7604
#   Edges: 6811
#   Density: 0.000118
#   Is Directed: True
# ----------------------------------------
# Snapshot 884: snapshot_311.gpickle
#   Nodes: 7604
#   Edges: 6824
#   Density: 0.000118
#   Is Directed: True
# ----------------------------------------
# Snapshot 885: snapshot_312.gpickle
#   Nodes: 7604
#   Edges: 6831
#   Density: 0.000118
#   Is Directed: True
# ----------------------------------------
# Snapshot 886: snapshot_313.gpickle
#   Nodes: 7604
#   Edges: 6843
#   Density: 0.000118
#   Is Directed: True
# ----------------------------------------
# Snapshot 887: snapshot_314.gpickle
#   Nodes: 7604
#   Edges: 6849
#   Density: 0.000118
#   Is Directed: True
# ----------------------------------------
# Snapshot 888: snapshot_315.gpickle
#   Nodes: 7604
#   Edges: 6857
#   Density: 0.000119
#   Is Directed: True
# ----------------------------------------
# Snapshot 889: snapshot_316.gpickle
#   Nodes: 7604
#   Edges: 6862
#   Density: 0.000119
#   Is Directed: True
# ----------------------------------------
# Snapshot 890: snapshot_317.gpickle
#   Nodes: 7604
#   Edges: 6869
#   Density: 0.000119
#   Is Directed: True
# ----------------------------------------
# Snapshot 891: snapshot_318.gpickle
#   Nodes: 7604
#   Edges: 6874
#   Density: 0.000119
#   Is Directed: True
# ----------------------------------------
# Snapshot 892: snapshot_319.gpickle
#   Nodes: 7604
#   Edges: 6890
#   Density: 0.000119
#   Is Directed: True
# ----------------------------------------
# Snapshot 893: snapshot_32.gpickle
#   Nodes: 7604
#   Edges: 82
#   Density: 0.000001
#   Is Directed: True
# ----------------------------------------
# Snapshot 894: snapshot_320.gpickle
#   Nodes: 7604
#   Edges: 6895
#   Density: 0.000119
#   Is Directed: True
# ----------------------------------------
# Snapshot 895: snapshot_321.gpickle
#   Nodes: 7604
#   Edges: 6911
#   Density: 0.000120
#   Is Directed: True
# ----------------------------------------
# Snapshot 896: snapshot_322.gpickle
#   Nodes: 7604
#   Edges: 6921
#   Density: 0.000120
#   Is Directed: True
# ----------------------------------------
# Snapshot 897: snapshot_323.gpickle
#   Nodes: 7604
#   Edges: 6930
#   Density: 0.000120
#   Is Directed: True
# ----------------------------------------
# Snapshot 898: snapshot_324.gpickle
#   Nodes: 7604
#   Edges: 6939
#   Density: 0.000120
#   Is Directed: True
# ----------------------------------------
# Snapshot 899: snapshot_325.gpickle
#   Nodes: 7604
#   Edges: 6948
#   Density: 0.000120
#   Is Directed: True
# ----------------------------------------
# Snapshot 900: snapshot_326.gpickle
#   Nodes: 7604
#   Edges: 6956
#   Density: 0.000120
#   Is Directed: True
# ----------------------------------------
# Snapshot 901: snapshot_327.gpickle
#   Nodes: 7604
#   Edges: 6964
#   Density: 0.000120
#   Is Directed: True
# ----------------------------------------
# Snapshot 902: snapshot_328.gpickle
#   Nodes: 7604
#   Edges: 6977
#   Density: 0.000121
#   Is Directed: True
# ----------------------------------------
# Snapshot 903: snapshot_329.gpickle
#   Nodes: 7604
#   Edges: 6983
#   Density: 0.000121
#   Is Directed: True
# ----------------------------------------
# Snapshot 904: snapshot_33.gpickle
#   Nodes: 7604
#   Edges: 84
#   Density: 0.000001
#   Is Directed: True
# ----------------------------------------
# Snapshot 905: snapshot_330.gpickle
#   Nodes: 7604
#   Edges: 6993
#   Density: 0.000121
#   Is Directed: True
# ----------------------------------------
# Snapshot 906: snapshot_331.gpickle
#   Nodes: 7604
#   Edges: 7001
#   Density: 0.000121
#   Is Directed: True
# ----------------------------------------
# Snapshot 907: snapshot_332.gpickle
#   Nodes: 7604
#   Edges: 7009
#   Density: 0.000121
#   Is Directed: True
# ----------------------------------------
# Snapshot 908: snapshot_333.gpickle
#   Nodes: 7604
#   Edges: 7021
#   Density: 0.000121
#   Is Directed: True
# ----------------------------------------
# Snapshot 909: snapshot_334.gpickle
#   Nodes: 7604
#   Edges: 7026
#   Density: 0.000122
#   Is Directed: True
# ----------------------------------------
# Snapshot 910: snapshot_335.gpickle
#   Nodes: 7604
#   Edges: 7038
#   Density: 0.000122
#   Is Directed: True
# ----------------------------------------
# Snapshot 911: snapshot_336.gpickle
#   Nodes: 7604
#   Edges: 7055
#   Density: 0.000122
#   Is Directed: True
# ----------------------------------------
# Snapshot 912: snapshot_337.gpickle
#   Nodes: 7604
#   Edges: 7070
#   Density: 0.000122
#   Is Directed: True
# ----------------------------------------
# Snapshot 913: snapshot_338.gpickle
#   Nodes: 7604
#   Edges: 7086
#   Density: 0.000123
#   Is Directed: True
# ----------------------------------------
# Snapshot 914: snapshot_339.gpickle
#   Nodes: 7604
#   Edges: 7100
#   Density: 0.000123
#   Is Directed: True
# ----------------------------------------
# Snapshot 915: snapshot_34.gpickle
#   Nodes: 7604
#   Edges: 91
#   Density: 0.000002
#   Is Directed: True
# ----------------------------------------
# Snapshot 916: snapshot_340.gpickle
#   Nodes: 7604
#   Edges: 7107
#   Density: 0.000123
#   Is Directed: True
# ----------------------------------------
# Snapshot 917: snapshot_341.gpickle
#   Nodes: 7604
#   Edges: 7119
#   Density: 0.000123
#   Is Directed: True
# ----------------------------------------
# Snapshot 918: snapshot_342.gpickle
#   Nodes: 7604
#   Edges: 7126
#   Density: 0.000123
#   Is Directed: True
# ----------------------------------------
# Snapshot 919: snapshot_343.gpickle
#   Nodes: 7604
#   Edges: 7142
#   Density: 0.000124
#   Is Directed: True
# ----------------------------------------
# Snapshot 920: snapshot_344.gpickle
#   Nodes: 7604
#   Edges: 7155
#   Density: 0.000124
#   Is Directed: True
# ----------------------------------------
# Snapshot 921: snapshot_345.gpickle
#   Nodes: 7604
#   Edges: 7165
#   Density: 0.000124
#   Is Directed: True
# ----------------------------------------
# Snapshot 922: snapshot_346.gpickle
#   Nodes: 7604
#   Edges: 7173
#   Density: 0.000124
#   Is Directed: True
# ----------------------------------------
# Snapshot 923: snapshot_347.gpickle
#   Nodes: 7604
#   Edges: 7175
#   Density: 0.000124
#   Is Directed: True
# ----------------------------------------
# Snapshot 924: snapshot_348.gpickle
#   Nodes: 7604
#   Edges: 7179
#   Density: 0.000124
#   Is Directed: True
# ----------------------------------------
# Snapshot 925: snapshot_349.gpickle
#   Nodes: 7604
#   Edges: 7182
#   Density: 0.000124
#   Is Directed: True
# ----------------------------------------
# Snapshot 926: snapshot_35.gpickle
#   Nodes: 7604
#   Edges: 93
#   Density: 0.000002
#   Is Directed: True
# ----------------------------------------
# Snapshot 927: snapshot_350.gpickle
#   Nodes: 7604
#   Edges: 7202
#   Density: 0.000125
#   Is Directed: True
# ----------------------------------------
# Snapshot 928: snapshot_351.gpickle
#   Nodes: 7604
#   Edges: 7214
#   Density: 0.000125
#   Is Directed: True
# ----------------------------------------
# Snapshot 929: snapshot_352.gpickle
#   Nodes: 7604
#   Edges: 7224
#   Density: 0.000125
#   Is Directed: True
# ----------------------------------------
# Snapshot 930: snapshot_353.gpickle
#   Nodes: 7604
#   Edges: 7232
#   Density: 0.000125
#   Is Directed: True
# ----------------------------------------
# Snapshot 931: snapshot_354.gpickle
#   Nodes: 7604
#   Edges: 7241
#   Density: 0.000125
#   Is Directed: True
# ----------------------------------------
# Snapshot 932: snapshot_355.gpickle
#   Nodes: 7604
#   Edges: 7246
#   Density: 0.000125
#   Is Directed: True
# ----------------------------------------
# Snapshot 933: snapshot_356.gpickle
#   Nodes: 7604
#   Edges: 7262
#   Density: 0.000126
#   Is Directed: True
# ----------------------------------------
# Snapshot 934: snapshot_357.gpickle
#   Nodes: 7604
#   Edges: 7268
#   Density: 0.000126
#   Is Directed: True
# ----------------------------------------
# Snapshot 935: snapshot_358.gpickle
#   Nodes: 7604
#   Edges: 7273
#   Density: 0.000126
#   Is Directed: True
# ----------------------------------------
# Snapshot 936: snapshot_359.gpickle
#   Nodes: 7604
#   Edges: 7291
#   Density: 0.000126
#   Is Directed: True
# ----------------------------------------
# Snapshot 937: snapshot_36.gpickle
#   Nodes: 7604
#   Edges: 98
#   Density: 0.000002
#   Is Directed: True
# ----------------------------------------
# Snapshot 938: snapshot_360.gpickle
#   Nodes: 7604
#   Edges: 7299
#   Density: 0.000126
#   Is Directed: True
# ----------------------------------------
# Snapshot 939: snapshot_361.gpickle
#   Nodes: 7604
#   Edges: 7326
#   Density: 0.000127
#   Is Directed: True
# ----------------------------------------
# Snapshot 940: snapshot_362.gpickle
#   Nodes: 7604
#   Edges: 7331
#   Density: 0.000127
#   Is Directed: True
# ----------------------------------------
# Snapshot 941: snapshot_363.gpickle
#   Nodes: 7604
#   Edges: 7339
#   Density: 0.000127
#   Is Directed: True
# ----------------------------------------
# Snapshot 942: snapshot_364.gpickle
#   Nodes: 7604
#   Edges: 7347
#   Density: 0.000127
#   Is Directed: True
# ----------------------------------------
# Snapshot 943: snapshot_365.gpickle
#   Nodes: 7604
#   Edges: 7362
#   Density: 0.000127
#   Is Directed: True
# ----------------------------------------
# Snapshot 944: snapshot_366.gpickle
#   Nodes: 7604
#   Edges: 7380
#   Density: 0.000128
#   Is Directed: True
# ----------------------------------------
# Snapshot 945: snapshot_367.gpickle
#   Nodes: 7604
#   Edges: 7390
#   Density: 0.000128
#   Is Directed: True
# ----------------------------------------
# Snapshot 946: snapshot_368.gpickle
#   Nodes: 7604
#   Edges: 7407
#   Density: 0.000128
#   Is Directed: True
# ----------------------------------------
# Snapshot 947: snapshot_369.gpickle
#   Nodes: 7604
#   Edges: 7414
#   Density: 0.000128
#   Is Directed: True
# ----------------------------------------
# Snapshot 948: snapshot_37.gpickle
#   Nodes: 7604
#   Edges: 101
#   Density: 0.000002
#   Is Directed: True
# ----------------------------------------
# Snapshot 949: snapshot_370.gpickle
#   Nodes: 7604
#   Edges: 7429
#   Density: 0.000129
#   Is Directed: True
# ----------------------------------------
# Snapshot 950: snapshot_371.gpickle
#   Nodes: 7604
#   Edges: 7447
#   Density: 0.000129
#   Is Directed: True
# ----------------------------------------
# Snapshot 951: snapshot_372.gpickle
#   Nodes: 7604
#   Edges: 7463
#   Density: 0.000129
#   Is Directed: True
# ----------------------------------------
# Snapshot 952: snapshot_373.gpickle
#   Nodes: 7604
#   Edges: 7476
#   Density: 0.000129
#   Is Directed: True
# ----------------------------------------
# Snapshot 953: snapshot_374.gpickle
#   Nodes: 7604
#   Edges: 7490
#   Density: 0.000130
#   Is Directed: True
# ----------------------------------------
# Snapshot 954: snapshot_375.gpickle
#   Nodes: 7604
#   Edges: 7492
#   Density: 0.000130
#   Is Directed: True
# ----------------------------------------
# Snapshot 955: snapshot_376.gpickle
#   Nodes: 7604
#   Edges: 7500
#   Density: 0.000130
#   Is Directed: True
# ----------------------------------------
# Snapshot 956: snapshot_377.gpickle
#   Nodes: 7604
#   Edges: 7517
#   Density: 0.000130
#   Is Directed: True
# ----------------------------------------
# Snapshot 957: snapshot_378.gpickle
#   Nodes: 7604
#   Edges: 7540
#   Density: 0.000130
#   Is Directed: True
# ----------------------------------------
# Snapshot 958: snapshot_379.gpickle
#   Nodes: 7604
#   Edges: 7559
#   Density: 0.000131
#   Is Directed: True
# ----------------------------------------
# Snapshot 959: snapshot_38.gpickle
#   Nodes: 7604
#   Edges: 105
#   Density: 0.000002
#   Is Directed: True
# ----------------------------------------
# Snapshot 960: snapshot_380.gpickle
#   Nodes: 7604
#   Edges: 7577
#   Density: 0.000131
#   Is Directed: True
# ----------------------------------------
# Snapshot 961: snapshot_381.gpickle
#   Nodes: 7604
#   Edges: 7602
#   Density: 0.000131
#   Is Directed: True
# ----------------------------------------
# Snapshot 962: snapshot_382.gpickle
#   Nodes: 7604
#   Edges: 7611
#   Density: 0.000132
#   Is Directed: True
# ----------------------------------------
# Snapshot 963: snapshot_383.gpickle
#   Nodes: 7604
#   Edges: 7629
#   Density: 0.000132
#   Is Directed: True
# ----------------------------------------
# Snapshot 964: snapshot_384.gpickle
#   Nodes: 7604
#   Edges: 7637
#   Density: 0.000132
#   Is Directed: True
# ----------------------------------------
# Snapshot 965: snapshot_385.gpickle
#   Nodes: 7604
#   Edges: 7649
#   Density: 0.000132
#   Is Directed: True
# ----------------------------------------
# Snapshot 966: snapshot_386.gpickle
#   Nodes: 7604
#   Edges: 7667
#   Density: 0.000133
#   Is Directed: True
# ----------------------------------------
# Snapshot 967: snapshot_387.gpickle
#   Nodes: 7604
#   Edges: 7684
#   Density: 0.000133
#   Is Directed: True
# ----------------------------------------
# Snapshot 968: snapshot_388.gpickle
#   Nodes: 7604
#   Edges: 7698
#   Density: 0.000133
#   Is Directed: True
# ----------------------------------------
# Snapshot 969: snapshot_389.gpickle
#   Nodes: 7604
#   Edges: 7701
#   Density: 0.000133
#   Is Directed: True
# ----------------------------------------
# Snapshot 970: snapshot_39.gpickle
#   Nodes: 7604
#   Edges: 108
#   Density: 0.000002
#   Is Directed: True
# ----------------------------------------
# Snapshot 971: snapshot_390.gpickle
#   Nodes: 7604
#   Edges: 7712
#   Density: 0.000133
#   Is Directed: True
# ----------------------------------------
# Snapshot 972: snapshot_391.gpickle
#   Nodes: 7604
#   Edges: 7733
#   Density: 0.000134
#   Is Directed: True
# ----------------------------------------
# Snapshot 973: snapshot_392.gpickle
#   Nodes: 7604
#   Edges: 7739
#   Density: 0.000134
#   Is Directed: True
# ----------------------------------------
# Snapshot 974: snapshot_393.gpickle
#   Nodes: 7604
#   Edges: 7751
#   Density: 0.000134
#   Is Directed: True
# ----------------------------------------
# Snapshot 975: snapshot_394.gpickle
#   Nodes: 7604
#   Edges: 7774
#   Density: 0.000134
#   Is Directed: True
# ----------------------------------------
# Snapshot 976: snapshot_395.gpickle
#   Nodes: 7604
#   Edges: 7785
#   Density: 0.000135
#   Is Directed: True
# ----------------------------------------
# Snapshot 977: snapshot_396.gpickle
#   Nodes: 7604
#   Edges: 7791
#   Density: 0.000135
#   Is Directed: True
# ----------------------------------------
# Snapshot 978: snapshot_397.gpickle
#   Nodes: 7604
#   Edges: 7805
#   Density: 0.000135
#   Is Directed: True
# ----------------------------------------
# Snapshot 979: snapshot_398.gpickle
#   Nodes: 7604
#   Edges: 7814
#   Density: 0.000135
#   Is Directed: True
# ----------------------------------------
# Snapshot 980: snapshot_399.gpickle
#   Nodes: 7604
#   Edges: 7829
#   Density: 0.000135
#   Is Directed: True
# ----------------------------------------
# Snapshot 981: snapshot_4.gpickle
#   Nodes: 7604
#   Edges: 17
#   Density: 0.000000
#   Is Directed: True
# ----------------------------------------
# Snapshot 982: snapshot_40.gpickle
#   Nodes: 7604
#   Edges: 114
#   Density: 0.000002
#   Is Directed: True
# ----------------------------------------
# Snapshot 983: snapshot_400.gpickle
#   Nodes: 7604
#   Edges: 7842
#   Density: 0.000136
#   Is Directed: True
# ----------------------------------------
# Snapshot 984: snapshot_401.gpickle
#   Nodes: 7604
#   Edges: 7854
#   Density: 0.000136
#   Is Directed: True
# ----------------------------------------
# Snapshot 985: snapshot_402.gpickle
#   Nodes: 7604
#   Edges: 7863
#   Density: 0.000136
#   Is Directed: True
# ----------------------------------------
# Snapshot 986: snapshot_403.gpickle
#   Nodes: 7604
#   Edges: 7875
#   Density: 0.000136
#   Is Directed: True
# ----------------------------------------
# Snapshot 987: snapshot_404.gpickle
#   Nodes: 7604
#   Edges: 7882
#   Density: 0.000136
#   Is Directed: True
# ----------------------------------------
# Snapshot 988: snapshot_405.gpickle
#   Nodes: 7604
#   Edges: 7884
#   Density: 0.000136
#   Is Directed: True
# ----------------------------------------
# Snapshot 989: snapshot_406.gpickle
#   Nodes: 7604
#   Edges: 7904
#   Density: 0.000137
#   Is Directed: True
# ----------------------------------------
# Snapshot 990: snapshot_407.gpickle
#   Nodes: 7604
#   Edges: 7921
#   Density: 0.000137
#   Is Directed: True
# ----------------------------------------
# Snapshot 991: snapshot_408.gpickle
#   Nodes: 7604
#   Edges: 7932
#   Density: 0.000137
#   Is Directed: True
# ----------------------------------------
# Snapshot 992: snapshot_409.gpickle
#   Nodes: 7604
#   Edges: 7952
#   Density: 0.000138
#   Is Directed: True
# ----------------------------------------
# Snapshot 993: snapshot_41.gpickle
#   Nodes: 7604
#   Edges: 119
#   Density: 0.000002
#   Is Directed: True
# ----------------------------------------
# Snapshot 994: snapshot_410.gpickle
#   Nodes: 7604
#   Edges: 7967
#   Density: 0.000138
#   Is Directed: True
# ----------------------------------------
# Snapshot 995: snapshot_411.gpickle
#   Nodes: 7604
#   Edges: 7983
#   Density: 0.000138
#   Is Directed: True
# ----------------------------------------
# Snapshot 996: snapshot_412.gpickle
#   Nodes: 7604
#   Edges: 7996
#   Density: 0.000138
#   Is Directed: True
# ----------------------------------------
# Snapshot 997: snapshot_413.gpickle
#   Nodes: 7604
#   Edges: 8014
#   Density: 0.000139
#   Is Directed: True
# ----------------------------------------
# Snapshot 998: snapshot_414.gpickle
#   Nodes: 7604
#   Edges: 8023
#   Density: 0.000139
#   Is Directed: True
# ----------------------------------------
# Snapshot 999: snapshot_415.gpickle
#   Nodes: 7604
#   Edges: 8035
#   Density: 0.000139
#   Is Directed: True
# ----------------------------------------
# Snapshot 1000: snapshot_416.gpickle
#   Nodes: 7604
#   Edges: 8038
#   Density: 0.000139
#   Is Directed: True
# ----------------------------------------
# Snapshot 1001: snapshot_417.gpickle
#   Nodes: 7604
#   Edges: 8046
#   Density: 0.000139
#   Is Directed: True
# ----------------------------------------
# Snapshot 1002: snapshot_418.gpickle
#   Nodes: 7604
#   Edges: 8065
#   Density: 0.000140
#   Is Directed: True
# ----------------------------------------
# Snapshot 1003: snapshot_419.gpickle
#   Nodes: 7604
#   Edges: 8074
#   Density: 0.000140
#   Is Directed: True
# ----------------------------------------
# Snapshot 1004: snapshot_42.gpickle
#   Nodes: 7604
#   Edges: 121
#   Density: 0.000002
#   Is Directed: True
# ----------------------------------------
# Snapshot 1005: snapshot_420.gpickle
#   Nodes: 7604
#   Edges: 8089
#   Density: 0.000140
#   Is Directed: True
# ----------------------------------------
# Snapshot 1006: snapshot_421.gpickle
#   Nodes: 7604
#   Edges: 8110
#   Density: 0.000140
#   Is Directed: True
# ----------------------------------------
# Snapshot 1007: snapshot_422.gpickle
#   Nodes: 7604
#   Edges: 8116
#   Density: 0.000140
#   Is Directed: True
# ----------------------------------------
# Snapshot 1008: snapshot_423.gpickle
#   Nodes: 7604
#   Edges: 8134
#   Density: 0.000141
#   Is Directed: True
# ----------------------------------------
# Snapshot 1009: snapshot_424.gpickle
#   Nodes: 7604
#   Edges: 8148
#   Density: 0.000141
#   Is Directed: True
# ----------------------------------------
# Snapshot 1010: snapshot_425.gpickle
#   Nodes: 7604
#   Edges: 8173
#   Density: 0.000141
#   Is Directed: True
# ----------------------------------------
# Snapshot 1011: snapshot_426.gpickle
#   Nodes: 7604
#   Edges: 8189
#   Density: 0.000142
#   Is Directed: True
# ----------------------------------------
# Snapshot 1012: snapshot_427.gpickle
#   Nodes: 7604
#   Edges: 8202
#   Density: 0.000142
#   Is Directed: True
# ----------------------------------------
# Snapshot 1013: snapshot_428.gpickle
#   Nodes: 7604
#   Edges: 8226
#   Density: 0.000142
#   Is Directed: True
# ----------------------------------------
# Snapshot 1014: snapshot_429.gpickle
#   Nodes: 7604
#   Edges: 8235
#   Density: 0.000142
#   Is Directed: True
# ----------------------------------------
# Snapshot 1015: snapshot_43.gpickle
#   Nodes: 7604
#   Edges: 122
#   Density: 0.000002
#   Is Directed: True
# ----------------------------------------
# Snapshot 1016: snapshot_430.gpickle
#   Nodes: 7604
#   Edges: 8245
#   Density: 0.000143
#   Is Directed: True
# ----------------------------------------
# Snapshot 1017: snapshot_431.gpickle
#   Nodes: 7604
#   Edges: 8251
#   Density: 0.000143
#   Is Directed: True
# ----------------------------------------
# Snapshot 1018: snapshot_432.gpickle
#   Nodes: 7604
#   Edges: 8276
#   Density: 0.000143
#   Is Directed: True
# ----------------------------------------
# Snapshot 1019: snapshot_433.gpickle
#   Nodes: 7604
#   Edges: 8291
#   Density: 0.000143
#   Is Directed: True
# ----------------------------------------
# Snapshot 1020: snapshot_434.gpickle
#   Nodes: 7604
#   Edges: 8308
#   Density: 0.000144
#   Is Directed: True
# ----------------------------------------
# Snapshot 1021: snapshot_435.gpickle
#   Nodes: 7604
#   Edges: 8326
#   Density: 0.000144
#   Is Directed: True
# ----------------------------------------
# Snapshot 1022: snapshot_436.gpickle
#   Nodes: 7604
#   Edges: 8334
#   Density: 0.000144
#   Is Directed: True
# ----------------------------------------
# Snapshot 1023: snapshot_437.gpickle
#   Nodes: 7604
#   Edges: 8362
#   Density: 0.000145
#   Is Directed: True
# ----------------------------------------
# Snapshot 1024: snapshot_438.gpickle
#   Nodes: 7604
#   Edges: 8382
#   Density: 0.000145
#   Is Directed: True
# ----------------------------------------
# Snapshot 1025: snapshot_439.gpickle
#   Nodes: 7604
#   Edges: 8397
#   Density: 0.000145
#   Is Directed: True
# ----------------------------------------
# Snapshot 1026: snapshot_44.gpickle
#   Nodes: 7604
#   Edges: 123
#   Density: 0.000002
#   Is Directed: True
# ----------------------------------------
# Snapshot 1027: snapshot_440.gpickle
#   Nodes: 7604
#   Edges: 8432
#   Density: 0.000146
#   Is Directed: True
# ----------------------------------------
# Snapshot 1028: snapshot_441.gpickle
#   Nodes: 7604
#   Edges: 8446
#   Density: 0.000146
#   Is Directed: True
# ----------------------------------------
# Snapshot 1029: snapshot_442.gpickle
#   Nodes: 7604
#   Edges: 8455
#   Density: 0.000146
#   Is Directed: True
# ----------------------------------------
# Snapshot 1030: snapshot_443.gpickle
#   Nodes: 7604
#   Edges: 8473
#   Density: 0.000147
#   Is Directed: True
# ----------------------------------------
# Snapshot 1031: snapshot_444.gpickle
#   Nodes: 7604
#   Edges: 8499
#   Density: 0.000147
#   Is Directed: True
# ----------------------------------------
# Snapshot 1032: snapshot_445.gpickle
#   Nodes: 7604
#   Edges: 8514
#   Density: 0.000147
#   Is Directed: True
# ----------------------------------------
# Snapshot 1033: snapshot_446.gpickle
#   Nodes: 7604
#   Edges: 8530
#   Density: 0.000148
#   Is Directed: True
# ----------------------------------------
# Snapshot 1034: snapshot_447.gpickle
#   Nodes: 7604
#   Edges: 8544
#   Density: 0.000148
#   Is Directed: True
# ----------------------------------------
# Snapshot 1035: snapshot_448.gpickle
#   Nodes: 7604
#   Edges: 8564
#   Density: 0.000148
#   Is Directed: True
# ----------------------------------------
# Snapshot 1036: snapshot_449.gpickle
#   Nodes: 7604
#   Edges: 8580
#   Density: 0.000148
#   Is Directed: True
# ----------------------------------------
# Snapshot 1037: snapshot_45.gpickle
#   Nodes: 7604
#   Edges: 128
#   Density: 0.000002
#   Is Directed: True
# ----------------------------------------
# Snapshot 1038: snapshot_450.gpickle
#   Nodes: 7604
#   Edges: 8599
#   Density: 0.000149
#   Is Directed: True
# ----------------------------------------
# Snapshot 1039: snapshot_451.gpickle
#   Nodes: 7604
#   Edges: 8619
#   Density: 0.000149
#   Is Directed: True
# ----------------------------------------
# Snapshot 1040: snapshot_452.gpickle
#   Nodes: 7604
#   Edges: 8633
#   Density: 0.000149
#   Is Directed: True
# ----------------------------------------
# Snapshot 1041: snapshot_453.gpickle
#   Nodes: 7604
#   Edges: 8651
#   Density: 0.000150
#   Is Directed: True
# ----------------------------------------
# Snapshot 1042: snapshot_454.gpickle
#   Nodes: 7604
#   Edges: 8656
#   Density: 0.000150
#   Is Directed: True
# ----------------------------------------
# Snapshot 1043: snapshot_455.gpickle
#   Nodes: 7604
#   Edges: 8669
#   Density: 0.000150
#   Is Directed: True
# ----------------------------------------
# Snapshot 1044: snapshot_456.gpickle
#   Nodes: 7604
#   Edges: 8686
#   Density: 0.000150
#   Is Directed: True
# ----------------------------------------
# Snapshot 1045: snapshot_457.gpickle
#   Nodes: 7604
#   Edges: 8700
#   Density: 0.000150
#   Is Directed: True
# ----------------------------------------
# Snapshot 1046: snapshot_458.gpickle
#   Nodes: 7604
#   Edges: 8709
#   Density: 0.000151
#   Is Directed: True
# ----------------------------------------
# Snapshot 1047: snapshot_459.gpickle
#   Nodes: 7604
#   Edges: 8718
#   Density: 0.000151
#   Is Directed: True
# ----------------------------------------
# Snapshot 1048: snapshot_46.gpickle
#   Nodes: 7604
#   Edges: 130
#   Density: 0.000002
#   Is Directed: True
# ----------------------------------------
# Snapshot 1049: snapshot_460.gpickle
#   Nodes: 7604
#   Edges: 8735
#   Density: 0.000151
#   Is Directed: True
# ----------------------------------------
# Snapshot 1050: snapshot_461.gpickle
#   Nodes: 7604
#   Edges: 8754
#   Density: 0.000151
#   Is Directed: True
# ----------------------------------------
# Snapshot 1051: snapshot_462.gpickle
#   Nodes: 7604
#   Edges: 8785
#   Density: 0.000152
#   Is Directed: True
# ----------------------------------------
# Snapshot 1052: snapshot_463.gpickle
#   Nodes: 7604
#   Edges: 8807
#   Density: 0.000152
#   Is Directed: True
# ----------------------------------------
# Snapshot 1053: snapshot_464.gpickle
#   Nodes: 7604
#   Edges: 8835
#   Density: 0.000153
#   Is Directed: True
# ----------------------------------------
# Snapshot 1054: snapshot_465.gpickle
#   Nodes: 7604
#   Edges: 8870
#   Density: 0.000153
#   Is Directed: True
# ----------------------------------------
# Snapshot 1055: snapshot_466.gpickle
#   Nodes: 7604
#   Edges: 8886
#   Density: 0.000154
#   Is Directed: True
# ----------------------------------------
# Snapshot 1056: snapshot_467.gpickle
#   Nodes: 7604
#   Edges: 8912
#   Density: 0.000154
#   Is Directed: True
# ----------------------------------------
# Snapshot 1057: snapshot_468.gpickle
#   Nodes: 7604
#   Edges: 8940
#   Density: 0.000155
#   Is Directed: True
# ----------------------------------------
# Snapshot 1058: snapshot_469.gpickle
#   Nodes: 7604
#   Edges: 8960
#   Density: 0.000155
#   Is Directed: True
# ----------------------------------------
# Snapshot 1059: snapshot_47.gpickle
#   Nodes: 7604
#   Edges: 133
#   Density: 0.000002
#   Is Directed: True
# ----------------------------------------
# Snapshot 1060: snapshot_470.gpickle
#   Nodes: 7604
#   Edges: 8980
#   Density: 0.000155
#   Is Directed: True
# ----------------------------------------
# Snapshot 1061: snapshot_471.gpickle
#   Nodes: 7604
#   Edges: 8991
#   Density: 0.000156
#   Is Directed: True
# ----------------------------------------
# Snapshot 1062: snapshot_472.gpickle
#   Nodes: 7604
#   Edges: 9007
#   Density: 0.000156
#   Is Directed: True
# ----------------------------------------
# Snapshot 1063: snapshot_473.gpickle
#   Nodes: 7604
#   Edges: 9012
#   Density: 0.000156
#   Is Directed: True
# ----------------------------------------
# Snapshot 1064: snapshot_474.gpickle
#   Nodes: 7604
#   Edges: 9036
#   Density: 0.000156
#   Is Directed: True
# ----------------------------------------
# Snapshot 1065: snapshot_475.gpickle
#   Nodes: 7604
#   Edges: 9059
#   Density: 0.000157
#   Is Directed: True
# ----------------------------------------
# Snapshot 1066: snapshot_476.gpickle
#   Nodes: 7604
#   Edges: 9070
#   Density: 0.000157
#   Is Directed: True
# ----------------------------------------
# Snapshot 1067: snapshot_477.gpickle
#   Nodes: 7604
#   Edges: 9078
#   Density: 0.000157
#   Is Directed: True
# ----------------------------------------
# Snapshot 1068: snapshot_478.gpickle
#   Nodes: 7604
#   Edges: 9096
#   Density: 0.000157
#   Is Directed: True
# ----------------------------------------
# Snapshot 1069: snapshot_479.gpickle
#   Nodes: 7604
#   Edges: 9129
#   Density: 0.000158
#   Is Directed: True
# ----------------------------------------
# Snapshot 1070: snapshot_48.gpickle
#   Nodes: 7604
#   Edges: 134
#   Density: 0.000002
#   Is Directed: True
# ----------------------------------------
# Snapshot 1071: snapshot_480.gpickle
#   Nodes: 7604
#   Edges: 9133
#   Density: 0.000158
#   Is Directed: True
# ----------------------------------------
# Snapshot 1072: snapshot_481.gpickle
#   Nodes: 7604
#   Edges: 9144
#   Density: 0.000158
#   Is Directed: True
# ----------------------------------------
# Snapshot 1073: snapshot_482.gpickle
#   Nodes: 7604
#   Edges: 9159
#   Density: 0.000158
#   Is Directed: True
# ----------------------------------------
# Snapshot 1074: snapshot_483.gpickle
#   Nodes: 7604
#   Edges: 9181
#   Density: 0.000159
#   Is Directed: True
# ----------------------------------------
# Snapshot 1075: snapshot_484.gpickle
#   Nodes: 7604
#   Edges: 9207
#   Density: 0.000159
#   Is Directed: True
# ----------------------------------------
# Snapshot 1076: snapshot_485.gpickle
#   Nodes: 7604
#   Edges: 9224
#   Density: 0.000160
#   Is Directed: True
# ----------------------------------------
# Snapshot 1077: snapshot_486.gpickle
#   Nodes: 7604
#   Edges: 9239
#   Density: 0.000160
#   Is Directed: True
# ----------------------------------------
# Snapshot 1078: snapshot_487.gpickle
#   Nodes: 7604
#   Edges: 9247
#   Density: 0.000160
#   Is Directed: True
# ----------------------------------------
# Snapshot 1079: snapshot_488.gpickle
#   Nodes: 7604
#   Edges: 9255
#   Density: 0.000160
#   Is Directed: True
# ----------------------------------------
# Snapshot 1080: snapshot_489.gpickle
#   Nodes: 7604
#   Edges: 9259
#   Density: 0.000160
#   Is Directed: True
# ----------------------------------------
# Snapshot 1081: snapshot_49.gpickle
#   Nodes: 7604
#   Edges: 137
#   Density: 0.000002
#   Is Directed: True
# ----------------------------------------
# Snapshot 1082: snapshot_490.gpickle
#   Nodes: 7604
#   Edges: 9287
#   Density: 0.000161
#   Is Directed: True
# ----------------------------------------
# Snapshot 1083: snapshot_491.gpickle
#   Nodes: 7604
#   Edges: 9310
#   Density: 0.000161
#   Is Directed: True
# ----------------------------------------
# Snapshot 1084: snapshot_492.gpickle
#   Nodes: 7604
#   Edges: 9321
#   Density: 0.000161
#   Is Directed: True
# ----------------------------------------
# Snapshot 1085: snapshot_493.gpickle
#   Nodes: 7604
#   Edges: 9337
#   Density: 0.000162
#   Is Directed: True
# ----------------------------------------
# Snapshot 1086: snapshot_494.gpickle
#   Nodes: 7604
#   Edges: 9366
#   Density: 0.000162
#   Is Directed: True
# ----------------------------------------
# Snapshot 1087: snapshot_495.gpickle
#   Nodes: 7604
#   Edges: 9377
#   Density: 0.000162
#   Is Directed: True
# ----------------------------------------
# Snapshot 1088: snapshot_496.gpickle
#   Nodes: 7604
#   Edges: 9396
#   Density: 0.000163
#   Is Directed: True
# ----------------------------------------
# Snapshot 1089: snapshot_497.gpickle
#   Nodes: 7604
#   Edges: 9418
#   Density: 0.000163
#   Is Directed: True
# ----------------------------------------
# Snapshot 1090: snapshot_498.gpickle
#   Nodes: 7604
#   Edges: 9438
#   Density: 0.000163
#   Is Directed: True
# ----------------------------------------
# Snapshot 1091: snapshot_499.gpickle
#   Nodes: 7604
#   Edges: 9461
#   Density: 0.000164
#   Is Directed: True
# ----------------------------------------
# Snapshot 1092: snapshot_5.gpickle
#   Nodes: 7604
#   Edges: 20
#   Density: 0.000000
#   Is Directed: True
# ----------------------------------------
# Snapshot 1093: snapshot_50.gpickle
#   Nodes: 7604
#   Edges: 138
#   Density: 0.000002
#   Is Directed: True
# ----------------------------------------
# Snapshot 1094: snapshot_500.gpickle
#   Nodes: 7604
#   Edges: 9479
#   Density: 0.000164
#   Is Directed: True
# ----------------------------------------
# Snapshot 1095: snapshot_501.gpickle
#   Nodes: 7604
#   Edges: 9511
#   Density: 0.000165
#   Is Directed: True
# ----------------------------------------
# Snapshot 1096: snapshot_502.gpickle
#   Nodes: 7604
#   Edges: 9539
#   Density: 0.000165
#   Is Directed: True
# ----------------------------------------
# Snapshot 1097: snapshot_503.gpickle
#   Nodes: 7604
#   Edges: 9569
#   Density: 0.000166
#   Is Directed: True
# ----------------------------------------
# Snapshot 1098: snapshot_504.gpickle
#   Nodes: 7604
#   Edges: 9591
#   Density: 0.000166
#   Is Directed: True
# ----------------------------------------
# Snapshot 1099: snapshot_505.gpickle
#   Nodes: 7604
#   Edges: 9613
#   Density: 0.000166
#   Is Directed: True
# ----------------------------------------
# Snapshot 1100: snapshot_506.gpickle
#   Nodes: 7604
#   Edges: 9638
#   Density: 0.000167
#   Is Directed: True
# ----------------------------------------
# Snapshot 1101: snapshot_507.gpickle
#   Nodes: 7604
#   Edges: 9652
#   Density: 0.000167
#   Is Directed: True
# ----------------------------------------
# Snapshot 1102: snapshot_508.gpickle
#   Nodes: 7604
#   Edges: 9665
#   Density: 0.000167
#   Is Directed: True
# ----------------------------------------
# Snapshot 1103: snapshot_509.gpickle
#   Nodes: 7604
#   Edges: 9682
#   Density: 0.000167
#   Is Directed: True
# ----------------------------------------
# Snapshot 1104: snapshot_51.gpickle
#   Nodes: 7604
#   Edges: 140
#   Density: 0.000002
#   Is Directed: True
# ----------------------------------------
# Snapshot 1105: snapshot_510.gpickle
#   Nodes: 7604
#   Edges: 9700
#   Density: 0.000168
#   Is Directed: True
# ----------------------------------------
# Snapshot 1106: snapshot_511.gpickle
#   Nodes: 7604
#   Edges: 9719
#   Density: 0.000168
#   Is Directed: True
# ----------------------------------------
# Snapshot 1107: snapshot_512.gpickle
#   Nodes: 7604
#   Edges: 9743
#   Density: 0.000169
#   Is Directed: True
# ----------------------------------------
# Snapshot 1108: snapshot_513.gpickle
#   Nodes: 7604
#   Edges: 9761
#   Density: 0.000169
#   Is Directed: True
# ----------------------------------------
# Snapshot 1109: snapshot_514.gpickle
#   Nodes: 7604
#   Edges: 9784
#   Density: 0.000169
#   Is Directed: True
# ----------------------------------------
# Snapshot 1110: snapshot_515.gpickle
#   Nodes: 7604
#   Edges: 9800
#   Density: 0.000170
#   Is Directed: True
# ----------------------------------------
# Snapshot 1111: snapshot_516.gpickle
#   Nodes: 7604
#   Edges: 9809
#   Density: 0.000170
#   Is Directed: True
# ----------------------------------------
# Snapshot 1112: snapshot_517.gpickle
#   Nodes: 7604
#   Edges: 9826
#   Density: 0.000170
#   Is Directed: True
# ----------------------------------------
# Snapshot 1113: snapshot_518.gpickle
#   Nodes: 7604
#   Edges: 9844
#   Density: 0.000170
#   Is Directed: True
# ----------------------------------------
# Snapshot 1114: snapshot_519.gpickle
#   Nodes: 7604
#   Edges: 9861
#   Density: 0.000171
#   Is Directed: True
# ----------------------------------------
# Snapshot 1115: snapshot_52.gpickle
#   Nodes: 7604
#   Edges: 142
#   Density: 0.000002
#   Is Directed: True
# ----------------------------------------
# Snapshot 1116: snapshot_520.gpickle
#   Nodes: 7604
#   Edges: 9880
#   Density: 0.000171
#   Is Directed: True
# ----------------------------------------
# Snapshot 1117: snapshot_521.gpickle
#   Nodes: 7604
#   Edges: 9894
#   Density: 0.000171
#   Is Directed: True
# ----------------------------------------
# Snapshot 1118: snapshot_522.gpickle
#   Nodes: 7604
#   Edges: 9922
#   Density: 0.000172
#   Is Directed: True
# ----------------------------------------
# Snapshot 1119: snapshot_523.gpickle
#   Nodes: 7604
#   Edges: 9938
#   Density: 0.000172
#   Is Directed: True
# ----------------------------------------
# Snapshot 1120: snapshot_524.gpickle
#   Nodes: 7604
#   Edges: 9949
#   Density: 0.000172
#   Is Directed: True
# ----------------------------------------
# Snapshot 1121: snapshot_525.gpickle
#   Nodes: 7604
#   Edges: 9958
#   Density: 0.000172
#   Is Directed: True
# ----------------------------------------
# Snapshot 1122: snapshot_526.gpickle
#   Nodes: 7604
#   Edges: 9973
#   Density: 0.000173
#   Is Directed: True
# ----------------------------------------
# Snapshot 1123: snapshot_527.gpickle
#   Nodes: 7604
#   Edges: 9991
#   Density: 0.000173
#   Is Directed: True
# ----------------------------------------
# Snapshot 1124: snapshot_528.gpickle
#   Nodes: 7604
#   Edges: 10014
#   Density: 0.000173
#   Is Directed: True
# ----------------------------------------
# Snapshot 1125: snapshot_529.gpickle
#   Nodes: 7604
#   Edges: 10027
#   Density: 0.000173
#   Is Directed: True
# ----------------------------------------
# Snapshot 1126: snapshot_53.gpickle
#   Nodes: 7604
#   Edges: 144
#   Density: 0.000002
#   Is Directed: True
# ----------------------------------------
# Snapshot 1127: snapshot_530.gpickle
#   Nodes: 7604
#   Edges: 10044
#   Density: 0.000174
#   Is Directed: True
# ----------------------------------------
# Snapshot 1128: snapshot_531.gpickle
#   Nodes: 7604
#   Edges: 10055
#   Density: 0.000174
#   Is Directed: True
# ----------------------------------------
# Snapshot 1129: snapshot_532.gpickle
#   Nodes: 7604
#   Edges: 10105
#   Density: 0.000175
#   Is Directed: True
# ----------------------------------------
# Snapshot 1130: snapshot_533.gpickle
#   Nodes: 7604
#   Edges: 10116
#   Density: 0.000175
#   Is Directed: True
# ----------------------------------------
# Snapshot 1131: snapshot_534.gpickle
#   Nodes: 7604
#   Edges: 10170
#   Density: 0.000176
#   Is Directed: True
# ----------------------------------------
# Snapshot 1132: snapshot_535.gpickle
#   Nodes: 7604
#   Edges: 10185
#   Density: 0.000176
#   Is Directed: True
# ----------------------------------------
# Snapshot 1133: snapshot_536.gpickle
#   Nodes: 7604
#   Edges: 10210
#   Density: 0.000177
#   Is Directed: True
# ----------------------------------------
# Snapshot 1134: snapshot_537.gpickle
#   Nodes: 7604
#   Edges: 10239
#   Density: 0.000177
#   Is Directed: True
# ----------------------------------------
# Snapshot 1135: snapshot_538.gpickle
#   Nodes: 7604
#   Edges: 10251
#   Density: 0.000177
#   Is Directed: True
# ----------------------------------------
# Snapshot 1136: snapshot_539.gpickle
#   Nodes: 7604
#   Edges: 10277
#   Density: 0.000178
#   Is Directed: True
# ----------------------------------------
# Snapshot 1137: snapshot_54.gpickle
#   Nodes: 7604
#   Edges: 147
#   Density: 0.000003
#   Is Directed: True
# ----------------------------------------
# Snapshot 1138: snapshot_540.gpickle
#   Nodes: 7604
#   Edges: 10292
#   Density: 0.000178
#   Is Directed: True
# ----------------------------------------
# Snapshot 1139: snapshot_541.gpickle
#   Nodes: 7604
#   Edges: 10319
#   Density: 0.000178
#   Is Directed: True
# ----------------------------------------
# Snapshot 1140: snapshot_542.gpickle
#   Nodes: 7604
#   Edges: 10343
#   Density: 0.000179
#   Is Directed: True
# ----------------------------------------
# Snapshot 1141: snapshot_543.gpickle
#   Nodes: 7604
#   Edges: 10350
#   Density: 0.000179
#   Is Directed: True
# ----------------------------------------
# Snapshot 1142: snapshot_544.gpickle
#   Nodes: 7604
#   Edges: 10367
#   Density: 0.000179
#   Is Directed: True
# ----------------------------------------
# Snapshot 1143: snapshot_545.gpickle
#   Nodes: 7604
#   Edges: 10402
#   Density: 0.000180
#   Is Directed: True
# ----------------------------------------
# Snapshot 1144: snapshot_546.gpickle
#   Nodes: 7604
#   Edges: 10436
#   Density: 0.000181
#   Is Directed: True
# ----------------------------------------
# Snapshot 1145: snapshot_547.gpickle
#   Nodes: 7604
#   Edges: 10461
#   Density: 0.000181
#   Is Directed: True
# ...
#   Nodes: 7604
#   Edges: 380
#   Density: 0.000007
#   Is Directed: True
# ----------------------------------------
# Snapshot 1538: snapshot_900.gpickle
#   Nodes: 7605
#   Edges: 18141
#   Density: 0.000314
#   Is Directed: True
# ----------------------------------------
# Snapshot 1539: snapshot_901.gpickle
#   Nodes: 7605
#   Edges: 18150
#   Density: 0.000314
#   Is Directed: True
# ----------------------------------------
# Snapshot 1540: snapshot_902.gpickle
#   Nodes: 7605
#   Edges: 18166
#   Density: 0.000314
#   Is Directed: True
# ----------------------------------------
# Snapshot 1541: snapshot_903.gpickle
#   Nodes: 7605
#   Edges: 18191
#   Density: 0.000315
#   Is Directed: True
# ----------------------------------------
# Snapshot 1542: snapshot_904.gpickle
#   Nodes: 7605
#   Edges: 18212
#   Density: 0.000315
#   Is Directed: True
# ----------------------------------------
# Snapshot 1543: snapshot_905.gpickle
#   Nodes: 7605
#   Edges: 18220
#   Density: 0.000315
#   Is Directed: True
# ----------------------------------------
# Snapshot 1544: snapshot_906.gpickle
#   Nodes: 7605
#   Edges: 18237
#   Density: 0.000315
#   Is Directed: True
# ----------------------------------------
# Snapshot 1545: snapshot_907.gpickle
#   Nodes: 7605
#   Edges: 18243
#   Density: 0.000315
#   Is Directed: True
# ----------------------------------------
# Snapshot 1546: snapshot_908.gpickle
#   Nodes: 7605
#   Edges: 18254
#   Density: 0.000316
#   Is Directed: True
# ----------------------------------------
# Snapshot 1547: snapshot_909.gpickle
#   Nodes: 7605
#   Edges: 18268
#   Density: 0.000316
#   Is Directed: True
# ----------------------------------------
# Snapshot 1548: snapshot_91.gpickle
#   Nodes: 7604
#   Edges: 385
#   Density: 0.000007
#   Is Directed: True
# ----------------------------------------
# Snapshot 1549: snapshot_910.gpickle
#   Nodes: 7605
#   Edges: 18296
#   Density: 0.000316
#   Is Directed: True
# ----------------------------------------
# Snapshot 1550: snapshot_911.gpickle
#   Nodes: 7605
#   Edges: 18308
#   Density: 0.000317
#   Is Directed: True
# ----------------------------------------
# Snapshot 1551: snapshot_912.gpickle
#   Nodes: 7605
#   Edges: 18328
#   Density: 0.000317
#   Is Directed: True
# ----------------------------------------
# Snapshot 1552: snapshot_913.gpickle
#   Nodes: 7605
#   Edges: 18340
#   Density: 0.000317
#   Is Directed: True
# ----------------------------------------
# Snapshot 1553: snapshot_914.gpickle
#   Nodes: 7605
#   Edges: 18353
#   Density: 0.000317
#   Is Directed: True
# ----------------------------------------
# Snapshot 1554: snapshot_915.gpickle
#   Nodes: 7605
#   Edges: 18362
#   Density: 0.000318
#   Is Directed: True
# ----------------------------------------
# Snapshot 1555: snapshot_916.gpickle
#   Nodes: 7605
#   Edges: 18372
#   Density: 0.000318
#   Is Directed: True
# ----------------------------------------
# Snapshot 1556: snapshot_917.gpickle
#   Nodes: 7605
#   Edges: 18388
#   Density: 0.000318
#   Is Directed: True
# ----------------------------------------
# Snapshot 1557: snapshot_918.gpickle
#   Nodes: 7605
#   Edges: 18401
#   Density: 0.000318
#   Is Directed: True
# ----------------------------------------
# Snapshot 1558: snapshot_919.gpickle
#   Nodes: 7605
#   Edges: 18418
#   Density: 0.000318
#   Is Directed: True
# ----------------------------------------
# Snapshot 1559: snapshot_92.gpickle
#   Nodes: 7604
#   Edges: 393
#   Density: 0.000007
#   Is Directed: True
# ----------------------------------------
# Snapshot 1560: snapshot_920.gpickle
#   Nodes: 7605
#   Edges: 18444
#   Density: 0.000319
#   Is Directed: True
# ----------------------------------------
# Snapshot 1561: snapshot_921.gpickle
#   Nodes: 7605
#   Edges: 18449
#   Density: 0.000319
#   Is Directed: True
# ----------------------------------------
# Snapshot 1562: snapshot_922.gpickle
#   Nodes: 7605
#   Edges: 18463
#   Density: 0.000319
#   Is Directed: True
# ----------------------------------------
# Snapshot 1563: snapshot_923.gpickle
#   Nodes: 7605
#   Edges: 18492
#   Density: 0.000320
#   Is Directed: True
# ----------------------------------------
# Snapshot 1564: snapshot_924.gpickle
#   Nodes: 7605
#   Edges: 18518
#   Density: 0.000320
#   Is Directed: True
# ----------------------------------------
# Snapshot 1565: snapshot_925.gpickle
#   Nodes: 7605
#   Edges: 18533
#   Density: 0.000320
#   Is Directed: True
# ----------------------------------------
# Snapshot 1566: snapshot_926.gpickle
#   Nodes: 7605
#   Edges: 18538
#   Density: 0.000321
#   Is Directed: True
# ----------------------------------------
# Snapshot 1567: snapshot_927.gpickle
#   Nodes: 7605
#   Edges: 18541
#   Density: 0.000321
#   Is Directed: True
# ----------------------------------------
# Snapshot 1568: snapshot_928.gpickle
#   Nodes: 7605
#   Edges: 18546
#   Density: 0.000321
#   Is Directed: True
# ----------------------------------------
# Snapshot 1569: snapshot_929.gpickle
#   Nodes: 7605
#   Edges: 18570
#   Density: 0.000321
#   Is Directed: True
# ----------------------------------------
# Snapshot 1570: snapshot_93.gpickle
#   Nodes: 7604
#   Edges: 394
#   Density: 0.000007
#   Is Directed: True
# ----------------------------------------
# Snapshot 1571: snapshot_930.gpickle
#   Nodes: 7605
#   Edges: 18573
#   Density: 0.000321
#   Is Directed: True
# ----------------------------------------
# Snapshot 1572: snapshot_931.gpickle
#   Nodes: 7605
#   Edges: 18584
#   Density: 0.000321
#   Is Directed: True
# ----------------------------------------
# Snapshot 1573: snapshot_932.gpickle
#   Nodes: 7605
#   Edges: 18607
#   Density: 0.000322
#   Is Directed: True
# ----------------------------------------
# Snapshot 1574: snapshot_933.gpickle
#   Nodes: 7605
#   Edges: 18629
#   Density: 0.000322
#   Is Directed: True
# ----------------------------------------
# Snapshot 1575: snapshot_934.gpickle
#   Nodes: 7605
#   Edges: 18651
#   Density: 0.000323
#   Is Directed: True
# ----------------------------------------
# Snapshot 1576: snapshot_935.gpickle
#   Nodes: 7605
#   Edges: 18657
#   Density: 0.000323
#   Is Directed: True
# ----------------------------------------
# Snapshot 1577: snapshot_936.gpickle
#   Nodes: 7605
#   Edges: 18664
#   Density: 0.000323
#   Is Directed: True
# ----------------------------------------
# Snapshot 1578: snapshot_937.gpickle
#   Nodes: 7605
#   Edges: 18675
#   Density: 0.000323
#   Is Directed: True
# ----------------------------------------
# Snapshot 1579: snapshot_938.gpickle
#   Nodes: 7605
#   Edges: 18691
#   Density: 0.000323
#   Is Directed: True
# ----------------------------------------
# Snapshot 1580: snapshot_939.gpickle
#   Nodes: 7605
#   Edges: 18711
#   Density: 0.000324
#   Is Directed: True
# ----------------------------------------
# Snapshot 1581: snapshot_94.gpickle
#   Nodes: 7604
#   Edges: 403
#   Density: 0.000007
#   Is Directed: True
# ----------------------------------------
# Snapshot 1582: snapshot_940.gpickle
#   Nodes: 7605
#   Edges: 18724
#   Density: 0.000324
#   Is Directed: True
# ----------------------------------------
# Snapshot 1583: snapshot_941.gpickle
#   Nodes: 7605
#   Edges: 18741
#   Density: 0.000324
#   Is Directed: True
# ----------------------------------------
# Snapshot 1584: snapshot_942.gpickle
#   Nodes: 7605
#   Edges: 18747
#   Density: 0.000324
#   Is Directed: True
# ----------------------------------------
# Snapshot 1585: snapshot_943.gpickle
#   Nodes: 7605
#   Edges: 18755
#   Density: 0.000324
#   Is Directed: True
# ----------------------------------------
# Snapshot 1586: snapshot_944.gpickle
#   Nodes: 7605
#   Edges: 18775
#   Density: 0.000325
#   Is Directed: True
# ----------------------------------------
# Snapshot 1587: snapshot_945.gpickle
#   Nodes: 7605
#   Edges: 18796
#   Density: 0.000325
#   Is Directed: True
# ----------------------------------------
# Snapshot 1588: snapshot_946.gpickle
#   Nodes: 7605
#   Edges: 18814
#   Density: 0.000325
#   Is Directed: True
# ----------------------------------------
# Snapshot 1589: snapshot_947.gpickle
#   Nodes: 7605
#   Edges: 18823
#   Density: 0.000325
#   Is Directed: True
# ----------------------------------------
# Snapshot 1590: snapshot_948.gpickle
#   Nodes: 7605
#   Edges: 18831
#   Density: 0.000326
#   Is Directed: True
# ----------------------------------------
# Snapshot 1591: snapshot_949.gpickle
#   Nodes: 7605
#   Edges: 18850
#   Density: 0.000326
#   Is Directed: True
# ----------------------------------------
# Snapshot 1592: snapshot_95.gpickle
#   Nodes: 7604
#   Edges: 408
#   Density: 0.000007
#   Is Directed: True
# ----------------------------------------
# Snapshot 1593: snapshot_950.gpickle
#   Nodes: 7605
#   Edges: 18859
#   Density: 0.000326
#   Is Directed: True
# ----------------------------------------
# Snapshot 1594: snapshot_951.gpickle
#   Nodes: 7605
#   Edges: 18878
#   Density: 0.000326
#   Is Directed: True
# ----------------------------------------
# Snapshot 1595: snapshot_952.gpickle
#   Nodes: 7605
#   Edges: 18906
#   Density: 0.000327
#   Is Directed: True
# ----------------------------------------
# Snapshot 1596: snapshot_953.gpickle
#   Nodes: 7605
#   Edges: 18928
#   Density: 0.000327
#   Is Directed: True
# ----------------------------------------
# Snapshot 1597: snapshot_954.gpickle
#   Nodes: 7605
#   Edges: 18944
#   Density: 0.000328
#   Is Directed: True
# ----------------------------------------
# Snapshot 1598: snapshot_955.gpickle
#   Nodes: 7605
#   Edges: 18999
#   Density: 0.000329
#   Is Directed: True
# ----------------------------------------
# Snapshot 1599: snapshot_956.gpickle
#   Nodes: 7605
#   Edges: 19016
#   Density: 0.000329
#   Is Directed: True
# ----------------------------------------
# Snapshot 1600: snapshot_957.gpickle
#   Nodes: 7605
#   Edges: 19031
#   Density: 0.000329
#   Is Directed: True
# ----------------------------------------
# Snapshot 1601: snapshot_958.gpickle
#   Nodes: 7605
#   Edges: 19046
#   Density: 0.000329
#   Is Directed: True
# ----------------------------------------
# Snapshot 1602: snapshot_959.gpickle
#   Nodes: 7605
#   Edges: 19059
#   Density: 0.000330
#   Is Directed: True
# ----------------------------------------
# Snapshot 1603: snapshot_96.gpickle
#   Nodes: 7604
#   Edges: 413
#   Density: 0.000007
#   Is Directed: True
# ----------------------------------------
# Snapshot 1604: snapshot_960.gpickle
#   Nodes: 7605
#   Edges: 19066
#   Density: 0.000330
#   Is Directed: True
# ----------------------------------------
# Snapshot 1605: snapshot_961.gpickle
#   Nodes: 7605
#   Edges: 19074
#   Density: 0.000330
#   Is Directed: True
# ----------------------------------------
# Snapshot 1606: snapshot_962.gpickle
#   Nodes: 7605
#   Edges: 19080
#   Density: 0.000330
#   Is Directed: True
# ----------------------------------------
# Snapshot 1607: snapshot_963.gpickle
#   Nodes: 7605
#   Edges: 19099
#   Density: 0.000330
#   Is Directed: True
# ----------------------------------------
# Snapshot 1608: snapshot_964.gpickle
#   Nodes: 7605
#   Edges: 19109
#   Density: 0.000330
#   Is Directed: True
# ----------------------------------------
# Snapshot 1609: snapshot_965.gpickle
#   Nodes: 7605
#   Edges: 19127
#   Density: 0.000331
#   Is Directed: True
# ----------------------------------------
# Snapshot 1610: snapshot_966.gpickle
#   Nodes: 7605
#   Edges: 19142
#   Density: 0.000331
#   Is Directed: True
# ----------------------------------------
# Snapshot 1611: snapshot_967.gpickle
#   Nodes: 7605
#   Edges: 19164
#   Density: 0.000331
#   Is Directed: True
# ----------------------------------------
# Snapshot 1612: snapshot_968.gpickle
#   Nodes: 7605
#   Edges: 19192
#   Density: 0.000332
#   Is Directed: True
# ----------------------------------------
# Snapshot 1613: snapshot_969.gpickle
#   Nodes: 7605
#   Edges: 19212
#   Density: 0.000332
#   Is Directed: True
# ----------------------------------------
# Snapshot 1614: snapshot_97.gpickle
#   Nodes: 7604
#   Edges: 417
#   Density: 0.000007
#   Is Directed: True
# ----------------------------------------
# Snapshot 1615: snapshot_970.gpickle
#   Nodes: 7605
#   Edges: 19228
#   Density: 0.000333
#   Is Directed: True
# ----------------------------------------
# Snapshot 1616: snapshot_971.gpickle
#   Nodes: 7605
#   Edges: 19239
#   Density: 0.000333
#   Is Directed: True
# ----------------------------------------
# Snapshot 1617: snapshot_972.gpickle
#   Nodes: 7605
#   Edges: 19261
#   Density: 0.000333
#   Is Directed: True
# ----------------------------------------
# Snapshot 1618: snapshot_973.gpickle
#   Nodes: 7605
#   Edges: 19272
#   Density: 0.000333
#   Is Directed: True
# ----------------------------------------
# Snapshot 1619: snapshot_974.gpickle
#   Nodes: 7605
#   Edges: 19287
#   Density: 0.000334
#   Is Directed: True
# ----------------------------------------
# Snapshot 1620: snapshot_975.gpickle
#   Nodes: 7605
#   Edges: 19292
#   Density: 0.000334
#   Is Directed: True
# ----------------------------------------
# Snapshot 1621: snapshot_976.gpickle
#   Nodes: 7605
#   Edges: 19298
#   Density: 0.000334
#   Is Directed: True
# ----------------------------------------
# Snapshot 1622: snapshot_977.gpickle
#   Nodes: 7605
#   Edges: 19306
#   Density: 0.000334
#   Is Directed: True
# ----------------------------------------
# Snapshot 1623: snapshot_978.gpickle
#   Nodes: 7605
#   Edges: 19324
#   Density: 0.000334
#   Is Directed: True
# ----------------------------------------
# Snapshot 1624: snapshot_979.gpickle
#   Nodes: 7605
#   Edges: 19339
#   Density: 0.000334
#   Is Directed: True
# ----------------------------------------
# Snapshot 1625: snapshot_98.gpickle
#   Nodes: 7604
#   Edges: 428
#   Density: 0.000007
#   Is Directed: True
# ----------------------------------------
# Snapshot 1626: snapshot_980.gpickle
#   Nodes: 7605
#   Edges: 19364
#   Density: 0.000335
#   Is Directed: True
# ----------------------------------------
# Snapshot 1627: snapshot_981.gpickle
#   Nodes: 7605
#   Edges: 19380
#   Density: 0.000335
#   Is Directed: True
# ----------------------------------------
# Snapshot 1628: snapshot_982.gpickle
#   Nodes: 7605
#   Edges: 19397
#   Density: 0.000335
#   Is Directed: True
# ----------------------------------------
# Snapshot 1629: snapshot_983.gpickle
#   Nodes: 7605
#   Edges: 19424
#   Density: 0.000336
#   Is Directed: True
# ----------------------------------------
# Snapshot 1630: snapshot_984.gpickle
#   Nodes: 7605
#   Edges: 19430
#   Density: 0.000336
#   Is Directed: True
# ----------------------------------------
# Snapshot 1631: snapshot_985.gpickle
#   Nodes: 7605
#   Edges: 19440
#   Density: 0.000336
#   Is Directed: True
# ----------------------------------------
# Snapshot 1632: snapshot_986.gpickle
#   Nodes: 7605
#   Edges: 19457
#   Density: 0.000336
#   Is Directed: True
# ----------------------------------------
# Snapshot 1633: snapshot_987.gpickle
#   Nodes: 7605
#   Edges: 19478
#   Density: 0.000337
#   Is Directed: True
# ----------------------------------------
# Snapshot 1634: snapshot_988.gpickle
#   Nodes: 7605
#   Edges: 19486
#   Density: 0.000337
#   Is Directed: True
# ----------------------------------------
# Snapshot 1635: snapshot_989.gpickle
#   Nodes: 7605
#   Edges: 19501
#   Density: 0.000337
#   Is Directed: True
# ----------------------------------------
# Snapshot 1636: snapshot_99.gpickle
#   Nodes: 7604
#   Edges: 435
#   Density: 0.000008
#   Is Directed: True
# ----------------------------------------
# Snapshot 1637: snapshot_990.gpickle
#   Nodes: 7605
#   Edges: 19521
#   Density: 0.000338
#   Is Directed: True
# ----------------------------------------
# Snapshot 1638: snapshot_991.gpickle
#   Nodes: 7605
#   Edges: 19530
#   Density: 0.000338
#   Is Directed: True
# ----------------------------------------
# Snapshot 1639: snapshot_992.gpickle
#   Nodes: 7605
#   Edges: 19533
#   Density: 0.000338
#   Is Directed: True
# ----------------------------------------
# Snapshot 1640: snapshot_993.gpickle
#   Nodes: 7605
#   Edges: 19543
#   Density: 0.000338
#   Is Directed: True
# ----------------------------------------
# Snapshot 1641: snapshot_994.gpickle
#   Nodes: 7605
#   Edges: 19557
#   Density: 0.000338
#   Is Directed: True
# ----------------------------------------
# Snapshot 1642: snapshot_995.gpickle
#   Nodes: 7605
#   Edges: 19564
#   Density: 0.000338
#   Is Directed: True
# ----------------------------------------
# Snapshot 1643: snapshot_996.gpickle
#   Nodes: 7605
#   Edges: 19573
#   Density: 0.000338
#   Is Directed: True
# ----------------------------------------
# Snapshot 1644: snapshot_997.gpickle
#   Nodes: 7605
#   Edges: 19590
#   Density: 0.000339
#   Is Directed: True
# ----------------------------------------
# Snapshot 1645: snapshot_998.gpickle
#   Nodes: 7605
#   Edges: 19600
#   Density: 0.000339
#   Is Directed: True
# ----------------------------------------
# Snapshot 1646: snapshot_999.gpickle
#   Nodes: 7605
#   Edges: 19607
#   Density: 0.000339
#   Is Directed: True
# ----------------------------------------

# %%
# get IFC centrality score for each node
def get_influence_capacity_scores(g, uniinfweight):
    nodelist = list(g.nodes)
    il = np.zeros((len(nodelist), 1))
    ig = np.zeros((len(nodelist), 1))

    degn = max([nx.degree(g, ind) for ind in g.nodes])

    for countnode in range(len(nodelist)):
        tempw = 0
        for neighbnode in g.neighbors(nodelist[countnode]):
            tempw = tempw + uniinfweight * uniinfweight * nx.degree(g, neighbnode)

        # local score
        il[nodelist[countnode]] = 1 + list(g.degree([nodelist[countnode]], weight='weight'))[0][1] + tempw

        # global score
        ig[nodelist[countnode]] = nx.core_number(g)[nodelist[countnode]] * (
                    1 + (nx.degree(g, nodelist[countnode])) / (degn))

    # overall score
    ic = np.array([(il[nodelist[countnode]] / np.max(il)) * (ig[nodelist[countnode]] / np.max(ig)) for countnode in
                range(len(nodelist))])

    return ic.flatten(), nodelist

# %%
import os
import pickle
import numpy as np
import networkx as nx

def add_features_and_labels_to_graphs(input_dir, output_dir, uniinfweight):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for file_name in os.listdir(input_dir):
        if file_name.endswith('.gpickle'):
            graph_path = os.path.join(input_dir, file_name)

            # ✅ Load graph with pickle
            with open(graph_path, "rb") as f:
                G = pickle.load(f)

            num_nodes, num_edges = G.number_of_nodes(), G.number_of_edges()
            print(f"{graph_path}: Nodes={num_nodes}, Edges={num_edges}")

            # Replace this with your own influence score function
            ic_scores, nodelist = get_influence_capacity_scores(G, uniinfweight)

            threshold = np.percentile(ic_scores, 70)

            for countnode, node in enumerate(nodelist):
                G.nodes[node]['feature'] = [
                    nx.degree(G, node),
                    nx.average_neighbor_degree(G, nodes=[node])[node],
                    1, 1, 1
                ]
                G.nodes[node]['label'] = int(ic_scores[countnode] >= threshold)

            # ✅ Save graph with pickle
            output_path = os.path.join(output_dir, file_name)
            with open(output_path, "wb") as f:
                pickle.dump(G, f)

            print(f"Processed and saved: {output_path}")

# %%
# Specify the directory where you want to save the graphs in Colab
out_graph_dir = "/content/bit-coin-alpha-labels-3"
input_directory = "/content/bit-coin-alpha"

# Make sure the directories exist (Colab will create them if not)
import os
os.makedirs(out_graph_dir, exist_ok=True)
os.makedirs(input_directory, exist_ok=True)  # only needed if uploading files later

# Call the function to add features and labels to graphs and save them
add_features_and_labels_to_graphs(input_directory, out_graph_dir, uniinfweight=1)
# Out:
# /content/bit-coin-alpha/snapshot_549.gpickle: Nodes=7604, Edges=10502
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_549.gpickle
# /content/bit-coin-alpha/snapshot_168.gpickle: Nodes=7604, Edges=2600
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_168.gpickle
# /content/bit-coin-alpha/snapshot_396.gpickle: Nodes=7604, Edges=7791
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_396.gpickle
# /content/bit-coin-alpha/snapshot_83.gpickle: Nodes=7604, Edges=330
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_83.gpickle
# /content/bit-coin-alpha/snapshot_583.gpickle: Nodes=7604, Edges=11229
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_583.gpickle
# /content/bit-coin-alpha/snapshot_98.gpickle: Nodes=7604, Edges=428
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_98.gpickle
# /content/bit-coin-alpha/snapshot_410.gpickle: Nodes=7604, Edges=7967
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_410.gpickle
# /content/bit-coin-alpha/snapshot_19.gpickle: Nodes=7604, Edges=46
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_19.gpickle
# /content/bit-coin-alpha/snapshot_563.gpickle: Nodes=7604, Edges=10831
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_563.gpickle
# /content/bit-coin-alpha/snapshot_52.gpickle: Nodes=7604, Edges=142
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_52.gpickle
# /content/bit-coin-alpha/snapshot_256.gpickle: Nodes=7604, Edges=6280
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_256.gpickle
# /content/bit-coin-alpha/snapshot_121.gpickle: Nodes=7604, Edges=611
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_121.gpickle
# /content/bit-coin-alpha/snapshot_486.gpickle: Nodes=7604, Edges=9239
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_486.gpickle
# /content/bit-coin-alpha/snapshot_314.gpickle: Nodes=7604, Edges=6849
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_314.gpickle
# /content/bit-coin-alpha/snapshot_539.gpickle: Nodes=7604, Edges=10277
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_539.gpickle
# /content/bit-coin-alpha/snapshot_238.gpickle: Nodes=7604, Edges=5990
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_238.gpickle
# /content/bit-coin-alpha/snapshot_331.gpickle: Nodes=7604, Edges=7001
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_331.gpickle
# /content/bit-coin-alpha/snapshot_227.gpickle: Nodes=7604, Edges=5848
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_227.gpickle
# /content/bit-coin-alpha/snapshot_498.gpickle: Nodes=7604, Edges=9438
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_498.gpickle
# /content/bit-coin-alpha/snapshot_432.gpickle: Nodes=7604, Edges=8276
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_432.gpickle
# /content/bit-coin-alpha/snapshot_174.gpickle: Nodes=7604, Edges=2904
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_174.gpickle
# /content/bit-coin-alpha/snapshot_333.gpickle: Nodes=7604, Edges=7021
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_333.gpickle
# /content/bit-coin-alpha/snapshot_103.gpickle: Nodes=7604, Edges=443
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_103.gpickle
# /content/bit-coin-alpha/snapshot_74.gpickle: Nodes=7604, Edges=271
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_74.gpickle
# /content/bit-coin-alpha/snapshot_422.gpickle: Nodes=7604, Edges=8116
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_422.gpickle
# /content/bit-coin-alpha/snapshot_46.gpickle: Nodes=7604, Edges=130
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_46.gpickle
# /content/bit-coin-alpha/snapshot_547.gpickle: Nodes=7604, Edges=10461
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_547.gpickle
# /content/bit-coin-alpha/snapshot_471.gpickle: Nodes=7604, Edges=8991
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_471.gpickle
# /content/bit-coin-alpha/snapshot_165.gpickle: Nodes=7604, Edges=2422
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_165.gpickle
# /content/bit-coin-alpha/snapshot_51.gpickle: Nodes=7604, Edges=140
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_51.gpickle
# /content/bit-coin-alpha/snapshot_163.gpickle: Nodes=7604, Edges=2311
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_163.gpickle
# /content/bit-coin-alpha/snapshot_427.gpickle: Nodes=7604, Edges=8202
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_427.gpickle
# /content/bit-coin-alpha/snapshot_621.gpickle: Nodes=7604, Edges=12068
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_621.gpickle
# /content/bit-coin-alpha/snapshot_529.gpickle: Nodes=7604, Edges=10027
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_529.gpickle
# /content/bit-coin-alpha/snapshot_615.gpickle: Nodes=7604, Edges=11927
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_615.gpickle
# /content/bit-coin-alpha/snapshot_117.gpickle: Nodes=7604, Edges=545
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_117.gpickle
# /content/bit-coin-alpha/snapshot_72.gpickle: Nodes=7604, Edges=244
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_72.gpickle
# /content/bit-coin-alpha/snapshot_56.gpickle: Nodes=7604, Edges=156
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_56.gpickle
# /content/bit-coin-alpha/snapshot_389.gpickle: Nodes=7604, Edges=7701
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_389.gpickle
# /content/bit-coin-alpha/snapshot_384.gpickle: Nodes=7604, Edges=7637
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_384.gpickle
# /content/bit-coin-alpha/snapshot_465.gpickle: Nodes=7604, Edges=8870
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_465.gpickle
# /content/bit-coin-alpha/snapshot_187.gpickle: Nodes=7604, Edges=4591
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_187.gpickle
# /content/bit-coin-alpha/snapshot_18.gpickle: Nodes=7604, Edges=44
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_18.gpickle
# /content/bit-coin-alpha/snapshot_201.gpickle: Nodes=7604, Edges=5269
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_201.gpickle
# /content/bit-coin-alpha/snapshot_367.gpickle: Nodes=7604, Edges=7390
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_367.gpickle
# /content/bit-coin-alpha/snapshot_574.gpickle: Nodes=7604, Edges=11067
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_574.gpickle
# /content/bit-coin-alpha/snapshot_640.gpickle: Nodes=7604, Edges=12452
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_640.gpickle
# /content/bit-coin-alpha/snapshot_319.gpickle: Nodes=7604, Edges=6890
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_319.gpickle
# /content/bit-coin-alpha/snapshot_73.gpickle: Nodes=7604, Edges=252
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_73.gpickle
# /content/bit-coin-alpha/snapshot_413.gpickle: Nodes=7604, Edges=8014
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_413.gpickle
# /content/bit-coin-alpha/snapshot_151.gpickle: Nodes=7604, Edges=1518
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_151.gpickle
# /content/bit-coin-alpha/snapshot_104.gpickle: Nodes=7604, Edges=446
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_104.gpickle
# /content/bit-coin-alpha/snapshot_351.gpickle: Nodes=7604, Edges=7214
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_351.gpickle
# /content/bit-coin-alpha/snapshot_414.gpickle: Nodes=7604, Edges=8023
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_414.gpickle
# /content/bit-coin-alpha/snapshot_270.gpickle: Nodes=7604, Edges=6483
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_270.gpickle
# /content/bit-coin-alpha/snapshot_522.gpickle: Nodes=7604, Edges=9922
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_522.gpickle
# /content/bit-coin-alpha/snapshot_520.gpickle: Nodes=7604, Edges=9880
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_520.gpickle
# /content/bit-coin-alpha/snapshot_332.gpickle: Nodes=7604, Edges=7009
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_332.gpickle
# /content/bit-coin-alpha/snapshot_23.gpickle: Nodes=7604, Edges=59
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_23.gpickle
# /content/bit-coin-alpha/snapshot_312.gpickle: Nodes=7604, Edges=6831
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_312.gpickle
# /content/bit-coin-alpha/snapshot_357.gpickle: Nodes=7604, Edges=7268
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_357.gpickle
# /content/bit-coin-alpha/snapshot_325.gpickle: Nodes=7604, Edges=6948
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_325.gpickle
# /content/bit-coin-alpha/snapshot_136.gpickle: Nodes=7604, Edges=853
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_136.gpickle
# /content/bit-coin-alpha/snapshot_22.gpickle: Nodes=7604, Edges=54
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_22.gpickle
# /content/bit-coin-alpha/snapshot_77.gpickle: Nodes=7604, Edges=296
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_77.gpickle
# /content/bit-coin-alpha/snapshot_626.gpickle: Nodes=7604, Edges=12181
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_626.gpickle
# /content/bit-coin-alpha/snapshot_171.gpickle: Nodes=7604, Edges=2782
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_171.gpickle
# /content/bit-coin-alpha/snapshot_146.gpickle: Nodes=7604, Edges=1223
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_146.gpickle
# /content/bit-coin-alpha/snapshot_96.gpickle: Nodes=7604, Edges=413
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_96.gpickle
# /content/bit-coin-alpha/snapshot_34.gpickle: Nodes=7604, Edges=91
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_34.gpickle
# /content/bit-coin-alpha/snapshot_593.gpickle: Nodes=7604, Edges=11495
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_593.gpickle
# /content/bit-coin-alpha/snapshot_379.gpickle: Nodes=7604, Edges=7559
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_379.gpickle
# /content/bit-coin-alpha/snapshot_554.gpickle: Nodes=7604, Edges=10622
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_554.gpickle
# /content/bit-coin-alpha/snapshot_289.gpickle: Nodes=7604, Edges=6682
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_289.gpickle
# /content/bit-coin-alpha/snapshot_648.gpickle: Nodes=7604, Edges=12650
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_648.gpickle
# /content/bit-coin-alpha/snapshot_59.gpickle: Nodes=7604, Edges=165
# Processed and saved: /content/bit-coin-alpha-labels-3/snapshot_59.gpickle
# /content/bit-coin-alpha/snapshot_338.gpickle: Nodes=7604, Edges=7086
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipython-input-44744793.py", line 11, in <cell line: 0>
#     add_features_and_labels_to_graphs(input_directory, out_graph_dir, uniinfweight=1)
#   File "/tmp/ipython-input-2380544915.py", line 22, in add_features_and_labels_to_graphs
#     ic_scores, nodelist = get_influence_capacity_scores(G, uniinfweight)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipython-input-3542533190.py", line 18, in get_influence_capacity_scores
#     ig[nodelist[countnode]] = nx.core_number(g)[nodelist[countnode]] * (
#                               ^^^^^^^^^^^^^^^^^
#   File "<class 'networkx.utils.decorators.argmap'> compilation 10", line 4, in argmap_core_number_6
#     import inspect
#             ^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/networkx/utils/backends.py", line 929, in _call_if_any_backends_installed
#     return self._call_with_backend(backend_name, args, kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/networkx/utils/backends.py", line 1463, in _call_with_backend
#     return self.orig_func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/networkx/algorithms/core.py", line None, in core_number
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1739, in getinnerframes
#     traceback_info = getframeinfo(tb, context)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1686, in getframeinfo
#     start = lineno - 1 - context//2
#             ~~~~~~~^~~
# TypeError: unsupported operand type(s) for -: 'NoneType' and 'int'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipython-input-44744793.py", line 11, in <cell line: 0>
#     add_features_and_labels_to_graphs(input_directory, out_graph_dir, uniinfweight=1)
#   File "/tmp/ipython-input-2380544915.py", line 22, in add_features_and_labels_to_graphs
#     ic_scores, nodelist = get_influence_capacity_scores(G, uniinfweight)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipython-input-3542533190.py", line 18, in get_influence_capacity_scores
#     ig[nodelist[countnode]] = nx.core_number(g)[nodelist[countnode]] * (
#                               ^^^^^^^^^^^^^^^^^
#   File "<class 'networkx.utils.decorators.argmap'> compilation 10", line 4, in argmap_core_number_6
#     import inspect
#             ^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/networkx/utils/backends.py", line 929, in _call_if_any_backends_installed
#     return self._call_with_backend(backend_name, args, kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/networkx/utils/backends.py", line 1463, in _call_with_backend
#     return self.orig_func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/networkx/algorithms/core.py", line None, in core_number
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
#            ^^^^^^^^^^^^
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1739, in getinnerframes
#     traceback_info = getframeinfo(tb, context)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1686, in getframeinfo
#     start = lineno - 1 - context//2
#             ~~~~~~~^~~
# TypeError: unsupported operand type(s) for -: 'NoneType' and 'int'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipython-input-44744793.py", line 11, in <cell line: 0>
#     add_features_and_labels_to_graphs(input_directory, out_graph_dir, uniinfweight=1)
#   File "/tmp/ipython-input-2380544915.py", line 22, in add_features_and_labels_to_graphs
#     ic_scores, nodelist = get_influence_capacity_scores(G, uniinfweight)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipython-input-3542533190.py", line 18, in get_influence_capacity_scores
#     ig[nodelist[countnode]] = nx.core_number(g)[nodelist[countnode]] * (
#                               ^^^^^^^^^^^^^^^^^
#   File "<class 'networkx.utils.decorators.argmap'> compilation 10", line 4, in argmap_core_number_6
#     import inspect
#             ^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/networkx/utils/backends.py", line 929, in _call_if_any_backends_installed
#     return self._call_with_backend(backend_name, args, kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/networkx/utils/backends.py", line 1463, in _call_with_backend
#     return self.orig_func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/networkx/algorithms/core.py", line None, in core_number
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
#            ^^^^^^^^^^^^
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#            ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
#            ^^^^^^^^^^^^
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1739, in getinnerframes
#     traceback_info = getframeinfo(tb, context)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1686, in getframeinfo
#     start = lineno - 1 - context//2
#             ~~~~~~~^~~
# TypeError: unsupported operand type(s) for -: 'NoneType' and 'int'

# %%
# === Run this in Colab ===

import os
import pickle
import networkx as nx
import matplotlib.pyplot as plt

# Your directories
out_graph_dir = "/content/bit-coin-alpha-labels-3"
input_directory = "/content/bit-coin-alpha"

# Load snapshot_18.gpickle from your output directory using pickle
g1_path = os.path.join(out_graph_dir, "snapshot_18.gpickle")
with open(g1_path, "rb") as f:
    g1 = pickle.load(f)

# --- Visualize the graph ---
plt.figure(figsize=(8, 6))
pos = nx.spring_layout(g1, seed=42)  # reproducible layout
nx.draw(
    g1, pos, with_labels=True,
    node_color="skyblue", edge_color="gray",
    node_size=400, font_size=8
)
plt.title("Snapshot 18 - Graph Visualization")
plt.show()

# --- Print a sample node with features and labels ---
print("\nAfter adding features and labels (showing 1 node only):")
for node, data in g1.nodes(data=True):
    print(node, data)
    break

# --- Count nodes with label 1 ---
count_label_1 = sum(
    1 for _, node_data in g1.nodes(data=True)
    if node_data.get("label") == 1
)
print(f"\nNumber of nodes with label 1: {count_label_1}")
# Out:
# After adding features and labels (showing 1 node only):
# 0 {'feature': [0, 0.0, 1, 1, 1], 'label': 1}
#
# Number of nodes with label 1: 7604

# %%
import os

# check directory contents
out_graph_dir = "/content/bit-coin-alpha-labels-3"

print("Does directory exist?", os.path.exists(out_graph_dir))
print("Files in directory:")
print(os.listdir(out_graph_dir)[:20])   # show first 20 files
# Out:
# Does directory exist? True
# Files in directory:
# ['snapshot_549.gpickle', 'snapshot_168.gpickle', 'snapshot_396.gpickle', 'snapshot_83.gpickle', 'snapshot_583.gpickle', 'snapshot_98.gpickle', 'snapshot_410.gpickle', 'snapshot_19.gpickle', 'snapshot_563.gpickle', 'snapshot_52.gpickle', 'snapshot_256.gpickle', 'snapshot_121.gpickle', 'snapshot_486.gpickle', 'snapshot_314.gpickle', 'snapshot_539.gpickle', 'snapshot_238.gpickle', 'snapshot_331.gpickle', 'snapshot_227.gpickle', 'snapshot_498.gpickle', 'snapshot_432.gpickle']

# %%
import pickle
import networkx as nx

# directories
out_graph_dir = "/content/bit-coin-alpha-labels-3"

## test snapshots
with open(out_graph_dir + "/snapshot_168.gpickle", "rb") as f:
    g1 = pickle.load(f)

print(list(g1.nodes(data=True))[0])   # first node + attributes
print(list(g1.edges(data=True))[0])   # first edge + attributes

print(list(g1.nodes(data=True))[4])   # 5th node + attributes
print(list(g1.edges(data=True))[3])   # 4th edge + attributes
## test snapshots
# Out:
# (0, {'feature': [0, 0.0, 1, 1, 1], 'label': 1})
# (1, 113, {'weight': 1})
# (4, {'feature': [229, 8.078947368421053, 1, 1, 1], 'label': 1})
# (1, 625, {'weight': 1})

# %%
nx.draw_networkx(g1, with_labels=True)

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Create a larger figure to give more space to the graph
fig, ax = plt.subplots(figsize=(12, 8))

# Position nodes using the spring layout with adjusted parameters for spacing
pos = nx.spring_layout(g1, k=0.5, iterations=20)

# Generate a color map for node labels
node_colors = ['red' if g1.nodes[node].get('label') == 1 else 'blue' for node in g1.nodes()]

# Draw the graph with the specified node colors and labels
nx.draw(
    g1, pos, ax=ax,
    node_color=node_colors,
    with_labels=True,
    node_size=500,
    font_size=8
)

# Draw the edges more faintly
nx.draw_networkx_edges(g1, pos, ax=ax, alpha=0.5)

# Add title and remove axis
ax.set_title('Graph Visualization (Red: Influential, Blue: Less Influential)', fontsize=14)
plt.axis('off')  # Hide axis ticks and labels
plt.show()

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Create a figure and axes
fig, ax = plt.subplots(figsize=(12, 8))

# Calculate layout for visualization
pos = nx.spring_layout(g1, k=0.5, iterations=20)

# Generate a color map for node labels
node_colors = ['red' if g1.nodes[node].get('label') == 1 else 'blue' for node in g1.nodes()]

# Draw nodes with specified options
nx.draw_networkx_nodes(g1, pos, node_color=node_colors, node_size=500, ax=ax)

# Draw edges more faintly
nx.draw_networkx_edges(g1, pos, alpha=0.5, ax=ax)

# Prepare node labels with degree information
node_labels = {node: str(deg) for node, deg in dict(g1.degree()).items()}
nx.draw_networkx_labels(g1, pos, labels=node_labels, font_size=8, ax=ax)

# Title and axis off
ax.set_title('Graph Visualization (Red: Influential, Blue: Less Influential)\nLabels = Node Degree', fontsize=14)
plt.axis('off')
plt.show()

# %%
import networkx as nx

# Check if the graph is strongly connected
if nx.is_strongly_connected(g1):
    print("The directed graph is strongly connected.")
else:
    print("The directed graph is not strongly connected.")

# Check if the graph is weakly connected
if nx.is_weakly_connected(g1):
    print("The directed graph is weakly connected.")
else:
    print("The directed graph is not weakly connected.")
# Out:
# The directed graph is not strongly connected.
# The directed graph is not weakly connected.

# %%
# Find isolated nodes in the graph
isolated_nodes = [node for node in g1.nodes if g1.degree(node) == 0]

print("Isolated nodes found in the graph:")
print(len(isolated_nodes) )
# Out:
# Isolated nodes found in the graph:
# 7005

# %%
import networkx as nx
import random
import os
import matplotlib.pyplot as plt

# %%
import networkx as nx
print(nx.__version__)
# Out:
# 3.5

# %%
import os
import random
import networkx as nx

# Parameters
num_nodes = 1000  # Number of nodes in the graph
initial_edges = 1  # Number of edges to attach from a new node to existing nodes in the Barabási-Albert graph
num_snapshots = 12  # Number of snapshots to generate
additional_edges_per_step = 50  # Number of edges to add at each step
edges_to_remove_per_snapshot = 100  # Number of edges to randomly remove in each snapshot
output_dir = "/content/barabasi_albert_snapshots_500"  # Directory to save the gpickle files

# Create the directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Generate the initial Barabási-Albert graph
G = nx.barabasi_albert_graph(num_nodes, initial_edges)

# Save the initial snapshot
initial_snapshot_path = os.path.join(output_dir, f"snapshot_0.gpickle")
#nx.write_gpickle(G, initial_snapshot_path)
pickle.dump(G, open(initial_snapshot_path, "wb"))
print(f"Snapshot 0: {G.number_of_nodes()} nodes, {G.number_of_edges()} edges saved to {initial_snapshot_path}")

# Generate additional snapshots with progressive edge additions and removals
for i in range(1, num_snapshots):
    # Add additional edges
    nodes = list(G.nodes())  # Convert NodeView to a list
    for _ in range(additional_edges_per_step):
        node1, node2 = random.sample(nodes, 2)  # pick 2 random nodes
        if not G.has_edge(node1, node2):  # avoid duplicate edges
            G.add_edge(node1, node2)

    # Remove edges
    edges = list(G.edges())  # Convert EdgeView to a list
    for _ in range(min(edges_to_remove_per_snapshot, len(edges))):  # avoid removing too many
        edge_to_remove = random.choice(edges)
        G.remove_edge(*edge_to_remove)
        edges.remove(edge_to_remove)  # update list

    # Save the graph snapshot
    snapshot_path = os.path.join(output_dir, f"snapshot_{i}.gpickle")
    pickle.dump(G, open(snapshot_path, "wb"))

    # Log snapshot info
    print(f"Snapshot {i}: {G.number_of_nodes()} nodes, {G.number_of_edges()} edges saved to {snapshot_path}")

print(f"\n✅ Generated {num_snapshots} snapshots with progressive edge additions/removals, saved to '{output_dir}'")
# Out:
# Snapshot 0: 1000 nodes, 999 edges saved to /content/barabasi_albert_snapshots_500/snapshot_0.gpickle
# Snapshot 1: 1000 nodes, 949 edges saved to /content/barabasi_albert_snapshots_500/snapshot_1.gpickle
# Snapshot 2: 1000 nodes, 899 edges saved to /content/barabasi_albert_snapshots_500/snapshot_2.gpickle
# Snapshot 3: 1000 nodes, 849 edges saved to /content/barabasi_albert_snapshots_500/snapshot_3.gpickle
# Snapshot 4: 1000 nodes, 799 edges saved to /content/barabasi_albert_snapshots_500/snapshot_4.gpickle
# Snapshot 5: 1000 nodes, 749 edges saved to /content/barabasi_albert_snapshots_500/snapshot_5.gpickle
# Snapshot 6: 1000 nodes, 698 edges saved to /content/barabasi_albert_snapshots_500/snapshot_6.gpickle
# Snapshot 7: 1000 nodes, 647 edges saved to /content/barabasi_albert_snapshots_500/snapshot_7.gpickle
# Snapshot 8: 1000 nodes, 597 edges saved to /content/barabasi_albert_snapshots_500/snapshot_8.gpickle
# Snapshot 9: 1000 nodes, 547 edges saved to /content/barabasi_albert_snapshots_500/snapshot_9.gpickle
# Snapshot 10: 1000 nodes, 497 edges saved to /content/barabasi_albert_snapshots_500/snapshot_10.gpickle
# Snapshot 11: 1000 nodes, 447 edges saved to /content/barabasi_albert_snapshots_500/snapshot_11.gpickle
#
# ✅ Generated 12 snapshots with progressive edge additions/removals, saved to '/content/barabasi_albert_snapshots_500'

# %%
import os
import pickle
import random
import matplotlib.pyplot as plt
import networkx as nx

# ✅ Change directory path (for Colab, use a folder in /content)
output_dir = "/content/barabasi_albert_snapshots_500"
os.makedirs(output_dir, exist_ok=True)

# ✅ Path to a processed graph file
processed_graph_path = os.path.join(output_dir, "snapshot_9.gpickle")  # replace snapshot_9.gpickle if needed

# ✅ Load the graph using pickle instead of nx.read_gpickle
with open(processed_graph_path, "rb") as f:
    G = pickle.load(f)

# ✅ Visualize the graph
plt.figure(figsize=(10, 8))
pos = nx.spring_layout(G)  # Compute layout for visualization
nx.draw(G, pos, with_labels=True, node_color="skyblue", edge_color="gray",
        node_size=500, font_size=10)
plt.title("Graph Visualization")
plt.show()

# ✅ Select a random node and print its details
random_node = random.choice(list(G.nodes))
node_data = G.nodes[random_node]

print(f"\nDetails of Node {random_node}:")
print(f"  Features: {node_data.get('features', 'No features found')}")
print(f"  Label: {node_data.get('label', 'No label found')}")
# Out:
# Details of Node 514:
#   Features: No features found
#   Label: No label found

# %%
import matplotlib.pyplot as plt
import networkx as nx
import os
import pickle

def plot_connected_components(directory_path, num_snapshots):
    """
    Plot the size of the largest connected component for each snapshot in the directory.

    Parameters:
        directory_path (str): Path to the directory containing graph snapshots.
        num_snapshots (int): Number of snapshots to process.
    """
    largest_components = []
    snapshots = []

    for i in range(num_snapshots):
        snapshot_path = os.path.join(directory_path, f"snapshot_{i}.gpickle")
        if os.path.exists(snapshot_path):
            # Read the graph using pickle (instead of nx.read_gpickle)
            with open(snapshot_path, "rb") as f:
                G = pickle.load(f)

            # If directed, convert to undirected before finding connected components
            if G.is_directed():
                G = G.to_undirected()

            # Compute the size of the largest connected component
            largest_cc = len(max(nx.connected_components(G), key=len))
            largest_components.append(largest_cc)
            snapshots.append(i)
        else:
            print(f"Snapshot {i} not found in {directory_path}")
            break

    # Plot
    plt.figure(figsize=(12, 6))
    plt.plot(snapshots, largest_components, marker='o', markersize=8, linewidth=2.5, label="Largest Connected Component")
    plt.title("Growth of Largest Connected Component in Snapshots", fontsize=14, fontweight='bold')
    plt.xlabel("Snapshot Number", fontsize=12, fontweight='bold')
    plt.ylabel("Size of Largest Connected Component", fontsize=12, fontweight='bold')
    plt.grid(visible=True, linestyle='--', alpha=0.6)
    plt.xticks(snapshots, fontsize=10)
    plt.yticks(fontsize=10)
    plt.legend(fontsize=12, loc='best')
    plt.tight_layout()
    plt.show()

# Directory containing the graph snapshots
output_dir = "/content/barabasi_albert_snapshots_500"  # adjust path in Colab

# Plot the size of the largest connected component for each snapshot
plot_connected_components(output_dir, num_snapshots=12)

# %%
import os
import random
import networkx as nx
import pickle

# Parameters
num_nodes = 1000  # Number of nodes in the graph
initial_edges = 1  # Number of edges to attach from a new node to existing nodes in the Barabási-Albert graph
num_snapshots = 15  # Number of snapshots to generate
edges_to_remove_per_snapshot = 50  # Number of edges to randomly remove in each snapshot (1-10)
additional_edges_per_step_1 = 1    # Number of edges to add in snapshots 1-10
additional_edges_per_step_2 = 200  # Number of edges to add in snapshots 11-15
output_dir = "/content/barabasi_albert_snapshots_1000"  # Directory to save the gpickle files

# Create the directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Generate the initial Barabási-Albert graph
G = nx.barabasi_albert_graph(num_nodes, initial_edges)

# Save the initial snapshot
initial_snapshot_path = os.path.join(output_dir, f"snapshot_0.gpickle")
with open(initial_snapshot_path, "wb") as f:
    pickle.dump(G, f)

print(f"Snapshot 0: {G.number_of_nodes()} nodes, {G.number_of_edges()} edges saved to {initial_snapshot_path}")

# Generate snapshots
for i in range(1, num_snapshots + 1):
    nodes = list(G.nodes())  # Convert NodeView to a list

    # Determine edge addition count based on snapshot range
    if i <= 10:
        additional_edges_per_step = additional_edges_per_step_1
    else:
        additional_edges_per_step = additional_edges_per_step_2

    # Add additional edges
    for _ in range(additional_edges_per_step):
        node1, node2 = random.sample(nodes, 2)
        if not G.has_edge(node1, node2):  # Avoid duplicate edges
            G.add_edge(node1, node2)

    # Remove edges only for snapshots 1-10
    if i <= 10:
        edges = list(G.edges())
        for _ in range(min(edges_to_remove_per_snapshot, len(edges))):
            edge_to_remove = random.choice(edges)
            G.remove_edge(*edge_to_remove)
            edges.remove(edge_to_remove)

    # Save the graph snapshot
    snapshot_path = os.path.join(output_dir, f"snapshot_{i}.gpickle")
    with open(snapshot_path, "wb") as f:
        pickle.dump(G, f)

    # Log the number of nodes and edges
    print(f"Snapshot {i}: {G.number_of_nodes()} nodes, {G.number_of_edges()} edges saved to {snapshot_path}")

print(f"\n✅ Generated {num_snapshots} snapshots with edge removal (1–10) and varying edge additions "
      f"(1–10: {additional_edges_per_step_1}, 11–15: {additional_edges_per_step_2}), saved to '{output_dir}'")
# Out:
# Snapshot 0: 1000 nodes, 999 edges saved to /content/barabasi_albert_snapshots_1000/snapshot_0.gpickle
# Snapshot 1: 1000 nodes, 950 edges saved to /content/barabasi_albert_snapshots_1000/snapshot_1.gpickle
# Snapshot 2: 1000 nodes, 901 edges saved to /content/barabasi_albert_snapshots_1000/snapshot_2.gpickle
# Snapshot 3: 1000 nodes, 852 edges saved to /content/barabasi_albert_snapshots_1000/snapshot_3.gpickle
# Snapshot 4: 1000 nodes, 803 edges saved to /content/barabasi_albert_snapshots_1000/snapshot_4.gpickle
# Snapshot 5: 1000 nodes, 754 edges saved to /content/barabasi_albert_snapshots_1000/snapshot_5.gpickle
# Snapshot 6: 1000 nodes, 705 edges saved to /content/barabasi_albert_snapshots_1000/snapshot_6.gpickle
# Snapshot 7: 1000 nodes, 656 edges saved to /content/barabasi_albert_snapshots_1000/snapshot_7.gpickle
# Snapshot 8: 1000 nodes, 607 edges saved to /content/barabasi_albert_snapshots_1000/snapshot_8.gpickle
# Snapshot 9: 1000 nodes, 558 edges saved to /content/barabasi_albert_snapshots_1000/snapshot_9.gpickle
# Snapshot 10: 1000 nodes, 509 edges saved to /content/barabasi_albert_snapshots_1000/snapshot_10.gpickle
# Snapshot 11: 1000 nodes, 709 edges saved to /content/barabasi_albert_snapshots_1000/snapshot_11.gpickle
# Snapshot 12: 1000 nodes, 908 edges saved to /content/barabasi_albert_snapshots_1000/snapshot_12.gpickle
# Snapshot 13: 1000 nodes, 1107 edges saved to /content/barabasi_albert_snapshots_1000/snapshot_13.gpickle
# Snapshot 14: 1000 nodes, 1307 edges saved to /content/barabasi_albert_snapshots_1000/snapshot_14.gpickle
# Snapshot 15: 1000 nodes, 1507 edges saved to /content/barabasi_albert_snapshots_1000/snapshot_15.gpickle
#
# ✅ Generated 15 snapshots with edge removal (1–10) and varying edge additions (1–10: 1, 11–15: 200), saved to '/content/barabasi_albert_snapshots_1000'

# %%
import matplotlib.pyplot as plt
import networkx as nx
import os
import pickle

def plot_connected_components(directory_path, num_snapshots):
    """
    Plot the size of the largest connected component for each snapshot in the directory.

    Parameters:
        directory_path (str): Path to the directory containing graph snapshots.
        num_snapshots (int): Number of snapshots to process.
    """
    largest_components = []
    snapshots = []

    for i in range(1, num_snapshots):
        snapshot_path = os.path.join(directory_path, f"snapshot_{i}.gpickle")
        if os.path.exists(snapshot_path):
            # Read the graph with pickle (instead of nx.read_gpickle)
            with open(snapshot_path, "rb") as f:
                G = pickle.load(f)

            # Convert directed to undirected (if needed)
            if G.is_directed():
                G = G.to_undirected()

            # Compute the size of the largest connected component
            largest_cc = len(max(nx.connected_components(G), key=len))
            largest_components.append(largest_cc)
            snapshots.append(i)
        else:
            print(f"Snapshot {i} not found in {directory_path}")
            break

    # Plot
    plt.figure(figsize=(12, 6))
    plt.plot(snapshots, largest_components, marker='o', markersize=8, linewidth=2.5, label="Largest Connected Component")
    plt.title("Growth of Largest Connected Component in Snapshots", fontsize=14, fontweight='bold')
    plt.xlabel("Snapshot Number", fontsize=12, fontweight='bold')
    plt.ylabel("Size of Largest Connected Component", fontsize=12, fontweight='bold')
    plt.grid(visible=True, linestyle='--', alpha=0.6)
    plt.xticks(snapshots, fontsize=10)
    plt.yticks(fontsize=10)
    plt.legend(fontsize=12, loc='best')
    plt.tight_layout()
    plt.show()



# Example: adjust path to your snapshots inside Drive
output_dir = "/content/barabasi_albert_snapshots_1000"

# Plot the size of the largest connected component for each snapshot
plot_connected_components(output_dir, num_snapshots=15)
